# %% [markdown]
# # Notebook for Programming in Problem 4
# Welcome to the programming portion of the assignment! Each assignment throughout the semester will have a written portion and a programming portion. We will be using [Google Colab](https://colab.research.google.com/notebooks/intro.ipynb#recent=true), so if you have never used it before, take a quick look through this introduction: [Working with Google Colab](https://docs.google.com/document/d/1LlnXoOblXwW3YX-0yG_5seTXJsb3kRdMMRYqs8Qqum4/edit?usp=sharing).

# %% [markdown]
# ## Learning Objectives
# In this problem, we will use [PyTorch](https://pytorch.org/) to implement a sequence-to-sequence (seq2seq) transformer model to build a nerual machine translation (NMT) system, which translates from French to English.

# %% [markdown]
# ## Writing Code
# Look for the keyword "TODO" and fill in your code in the empty space.
# You can edit code in the other parts of the notebook too, which can be useful for debugging, but be careful to avoid breaking the provided code.

# %% [markdown]
# ## Installing Packages
#
# Install PyTorch using pip. See [https://pytorch.org/](https://pytorch.org/) if you want to install it on your computer.
# In addition, we will also be needing [huggingface](https://huggingface.co/)'s `transformers` and `datasets` libraries, and [nltk](https://www.nltk.org/) to compute the BLEU score.

# %%
# Pytorch is typically already installed in Google Colab (uncomment to install):
# !pip install torch==1.8.0
# or for GPU support:
# !pip install torch==1.8.0+cu111 -f https://download.pytorch.org/whl/torch_stable.html
# !pip install transformers==4.27.0
# !pip install datasets==2.10.0
# NLTK is typically also already installed in Google Colab (uncomment to install):
# !pip install nltk==3.8.1
# Out:
# WARNING: Ignoring invalid distribution -atasets (/usr/local/lib/python3.10/dist-packages)
# Requirement already satisfied: transformers==4.27.0 in /usr/local/lib/python3.10/dist-packages (4.27.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers==4.27.0) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from transformers==4.27.0) (0.26.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.27.0) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers==4.27.0) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.27.0) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.27.0) (2024.9.11)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers==4.27.0) (2.32.3)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.27.0) (0.13.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers==4.27.0) (4.66.6)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers==4.27.0) (2024.9.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers==4.27.0) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.27.0) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.27.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.27.0) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.27.0) (2024.8.30)
# WARNING: Ignoring invalid distribution -atasets (/usr/local/lib/python3.10/dist-packages)
# WARNING: Ignoring invalid distribution -atasets (/usr/local/lib/python3.10/dist-packages)
# Collecting datasets==2.10.0
#   Using cached datasets-2.10.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets==2.10.0) (1.26.4)
# Requirement already satisfied: pyarrow>=6.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets==2.10.0) (17.0.0)
# Requirement already satisfied: dill<0.3.7,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets==2.10.0) (0.3.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets==2.10.0) (2.2.2)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets==2.10.0) (2.32.3)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets==2.10.0) (4.66.6)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets==2.10.0) (3.5.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets==2.10.0) (0.70.14)
# Requirement already satisfied: fsspec>=2021.11.1 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>=2021.11.1->datasets==2.10.0) (2024.9.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets==2.10.0) (3.11.2)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from datasets==2.10.0) (0.26.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets==2.10.0) (24.2)
# Requirement already satisfied: responses<0.19 in /usr/local/lib/python3.10/dist-packages (from datasets==2.10.0) (0.18.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets==2.10.0) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.10.0) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.10.0) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.10.0) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.10.0) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.10.0) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.10.0) (0.2.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.10.0) (1.17.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.10.0) (4.0.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.2.0->datasets==2.10.0) (3.16.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.2.0->datasets==2.10.0) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets==2.10.0) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets==2.10.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets==2.10.0) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets==2.10.0) (2024.8.30)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets==2.10.0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets==2.10.0) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets==2.10.0) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets==2.10.0) (1.16.0)
# Using cached datasets-2.10.0-py3-none-any.whl (469 kB)
# WARNING: Ignoring invalid distribution -atasets (/usr/local/lib/python3.10/dist-packages)
# Installing collected packages: datasets
#   Attempting uninstall: datasets
#     Found existing installation: datasets 3.1.0
#     Uninstalling datasets-3.1.0:
#       Successfully uninstalled datasets-3.1.0
# Successfully installed datasets-2.10.0

# %% [markdown]
# ## Download NMT data

# %% [markdown]
# We first download the data for NMT, which contains pairs of parallel sentences.

# %%
# !wget --quiet https://princeton-nlp.github.io/cos484/assignments/a4/resources.zip
# !unzip -qo resources.zip

# %%
# !pip install -U datasets
# Out:
# WARNING: Ignoring invalid distribution -atasets (/usr/local/lib/python3.10/dist-packages)
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (2.10.0)
# Collecting datasets
#   Using cached datasets-3.1.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.16.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (17.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.3.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.6)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.70.14)
# Requirement already satisfied: fsspec<=2024.9.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets) (2024.9.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.11.2)
# Requirement already satisfied: huggingface-hub>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.26.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (0.2.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.17.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.23.0->datasets) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2024.8.30)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Using cached datasets-3.1.0-py3-none-any.whl (480 kB)
# WARNING: Ignoring invalid distribution -atasets (/usr/local/lib/python3.10/dist-packages)
# Installing collected packages: datasets
#   Attempting uninstall: datasets
#     Found existing installation: datasets 2.10.0
#     Uninstalling datasets-2.10.0:
#       Successfully uninstalled datasets-2.10.0
# Successfully installed datasets-3.1.0

# %% [markdown]
# ## Data preprocessing
# In this section we will write code to load and tokenize the data for NMT.
#
#
# The parallel data is provided as huggingface datasets, one for each split of `train`, `validation` and `test`. We load it via the `load_from_disk` method and inspect its features. If you'd like to know more about these dataset objects, have a look at [this tutorial](https://huggingface.co/docs/datasets/access).

# %%
from datasets import load_from_disk
raw_text_datasets = load_from_disk("resources/parallel_en_fr_corpus")
print("Summary of splits:", raw_text_datasets)
print("First training example:", raw_text_datasets["train"][0])
# Out:
# Summary of splits: DatasetDict({
#     train: Dataset({
#         features: ['text_en', 'text_fr'],
#         num_rows: 8701
#     })
#     validation: Dataset({
#         features: ['text_en', 'text_fr'],
#         num_rows: 485
#     })
#     test: Dataset({
#         features: ['text_en', 'text_fr'],
#         num_rows: 486
#     })
# })
# First training example: {'text_en': 'i m tough .', 'text_fr': 'je suis dure .'}

# %% [markdown]
# You are also provided with two pre-trained tokenizers for the source and target languages respectively, which we can load with the hugginface transfomers library. [This tutorial](https://huggingface.co/docs/transformers/preprocessing#natural-language-processing) provides an introduction to using pre-trained tokenizers and the powerful `AutoTokenizer` class. The tokenizers are based on byte-pair encodings which break words into smaller units. This is aimed at reducing the sparsity of words, as subwords can be shared between different rare words. If you are interested in learning more, see the paper [Neural Machine Translation of Rare Words with Subword Units](https://www.aclweb.org/anthology/P16-1162.pdf).

# %%
from transformers import AutoTokenizer
source_tokenizer = AutoTokenizer.from_pretrained("resources/tokenizer_fr")
target_tokenizer = AutoTokenizer.from_pretrained("resources/tokenizer_en")

print("Vocab size of source language:", source_tokenizer.vocab_size)
print("Vocab size of target language:", target_tokenizer.vocab_size)

# As a demonstration, we will the following English sentence to tokens.
example_sentence = "we have an example"
tokenizer_output = target_tokenizer(example_sentence)
print("\n*** Example ***")
print("Example sentence:", example_sentence)
print("Tokenizer output:", tokenizer_output)

# We convert every token id to its associated string, but find the special character ▁ which indicates the beginning of a word.
# Note that very common words are represented by a single token, while others are split into subunits due to the small vocab size.
# Also note that †he tokenizer already adds special tokens to the beginning and end of the sentence.
decoded_sequence = [target_tokenizer.decode(token) for token in tokenizer_output["input_ids"]]
print("Tokens:", decoded_sequence)

# By replacing the special character ▁ with whitespace, we can reconstruct a legibile sentence,
# which differs from the original example by special tokens, includings <unk> tokens, and minor whitespace differences.
reconstructed = "".join(decoded_sequence).replace("▁", " ")
print("Reconstructed sentence", reconstructed)
# Out:
# Vocab size of source language: 3200
# Vocab size of target language: 3200
#
# *** Example ***
# Example sentence: we have an example
# Tokenizer output: {'input_ids': [1, 64, 324, 103, 266, 1490, 92, 2], 'token_type_ids': [0, 0, 0, 0, 0, 0, 0, 0], 'attention_mask': [1, 1, 1, 1, 1, 1, 1, 1]}
# Tokens: ['<s>', '▁we', '▁have', '▁an', '▁ex', 'amp', 'le', '</s>']
# Reconstructed sentence <s> we have an example</s>

# %% [markdown]
# We now want to convert the entire dataset to token ids.
# Specifically, we want to use the tokenizers to create a dataset with
# features "encoder_input_ids" and "decoder_input_ids", which both have type `List[int]`
# and which will later be the inputs to our encoder-decoder model. We will implement this using the powerful `map` function. You can find its API reference [here](https://huggingface.co/docs/datasets/v2.10.0/en/package_reference/main_classes#datasets.Dataset.map).

# %%
from typing import Dict, List

def map_example(example: Dict[str, str]) -> Dict[str, List[int]]:
    # TODO: Tokenize the source and target text for an entry in the parallel dataset
    # and return a dictionary with the keys "encoder_input_ids" and "decoder_input_ids".
    # You can use `source_tokenizer` and `target_tokenizer`
    encoder_input_ids=source_tokenizer(example["text_fr"])["input_ids"]
    decoder_input_ids=target_tokenizer(example["text_en"])["input_ids"]
    return {"encoder_input_ids": encoder_input_ids, "decoder_input_ids": decoder_input_ids}

    raise NotImplementedError("The map_item function is not implemented yet")

# When mapped is applied to the DatasetDict object, it will apply `map` separately to each split.
tokenized_datasets = raw_text_datasets.map(map_example, batched=False)

# The `remove_columns` removes the existing text features from the new dataset, as they are no longer needed.
tokenized_datasets = tokenized_datasets.remove_columns(raw_text_datasets.column_names["train"])

# Sanity checks on the new dataset
assert set(tokenized_datasets.column_names["train"]) == {"decoder_input_ids", "encoder_input_ids"}
assert len(tokenized_datasets["train"]) == len(raw_text_datasets["train"])

# %%
example_dataset = [
    {"text_en": "we have an example", "text_fr": "nous avons un exemple"}
]
mapped_example = map_example(example_dataset[0])

print("Mapped example:", mapped_example)
# Out:
# Mapped example: {'encoder_input_ids': [1, 79, 349, 82, 298, 13, 130, 52, 2], 'decoder_input_ids': [1, 64, 324, 103, 266, 1490, 92, 2]}

# %% [markdown]
# ## Transformer model for NMT

# %% [markdown]
# We will now implement a encoder-decoder transformer model.
# We already provide code for the Feedforward Layers and Transformer Blocks, but you will have to implement the MultiHeadAttention and Embedding layer from scratch, as well as registering all the layers in the final EncoderDecoderModel. Pay attention to doc-strings and typing information to understand the context and purpose of each missing code block!

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

import math
from typing import Optional, Dict, List, Tuple

# %%
class MultiHeadAttention(nn.Module):
    def __init__(self,
                 hidden_size: int,
                 num_attention_heads: int,
                 is_causal_attention: bool = False,
                 is_cross_attention: bool = False):
        """Defines a flexible multi-head attention layer.

        This layer should define parameters for the query, key and value projections, as well as the output projection,
        and implement the following steps:
        (1) Project the input vectors using query projection and key projection matrices.
        (2) Compute the head-wise attention scores scaled by 1/sqrt(head_dim)
        (3) Perform appropriate masking to the attention scores using key_padding_mask and optionally causal attention.
        (4) Normalize the head-wise attention scores using softmax.
        (5) Compute the value projections and then aggregate using the normalized attention scores.
        (6) Use the output projection to obtain the final output vectors.
        When is_cross_attention is True, the key and value projections are computed from the encoder outputs.
        Note that we do not use attention weight dropout in this implementation.

        Args:
            hidden_size: The dimensionality of the input vectors.
            num_attention_heads: The number of attention heads.
            is_causal_attention: Whether to use causal masking,
                    where tokens cannot attend to the future tokens on their right.
            is_cross_attention: Whether to use cross attention,
                    where we use different inputs for the key/value vs. query vectors.
        """
        super().__init__()
        assert hidden_size % num_attention_heads == 0, "The hidden size must be divisible by the number of attention heads."
        self.head_dim = hidden_size // num_attention_heads  # embedding dimension of query and key vectors per head

        # TODO Initialize the module and its parameters here.
        # This module should be able to handle both full self-attention, causal masked self-attention and cross-attention.
        # IMPORTANT: You are not allowed to use `nn.MultiheadAttention` or `nn.functional.scaled_dot_product_attention`!
        self.head_dim = hidden_size // num_attention_heads
        self.num_attention_heads = num_attention_heads
        self.is_causal_attention = is_causal_attention
        self.is_cross_attention = is_cross_attention

        self.query_proj = nn.Linear(hidden_size, hidden_size)
        self.key_proj = nn.Linear(hidden_size, hidden_size)
        self.value_proj = nn.Linear(hidden_size, hidden_size)

        self.out_proj= nn.Linear(hidden_size, hidden_size)




    def causal_attention_mask(self,
                              sequence_length: int,
                              device: Optional[torch.device] = None) -> torch.FloatTensor:
        """Return a Float tensor that can be added to the (un-normalized) attention scores for causal masking.

        Args:
            sequence_length: width and height of the attention mask tensor.
            device: which torch device the resulting tensor should be on (important if you use GPU).

        Returns:
            A Float tensor of shape (1, 1, sequence_length, sequence_length) on device `device`,
            where the entries above the diagonal contain large negative values,
            which means that a query at position i can't attend to a key at position j>i.
        """

        # TODO Implement the forward function.
        # IMPORTANT: For full credit, you should not use python loops.
        #
        # Hint 1: You can pick an arbitrary large value (e.g., -10^{6}), but note that
        #         using `float("-inf")` might lead to numerical issues and 'nan' values during training.
        #
        # Hint 2: Useful pytorch functions for this are `torch.arange` or `torch.triu`.
        #
        # Hint 3: You can move the tensor you create to a device by calling `tensor.to(device)`
        #
        # You should use this function in `forward` and use the returned tensor to implement causal masking
        # by adding it to the un-normalized attention scores of shape (batch_size, num_heads, sequence_length, sequence_length),
        # as torch will handle broadcasting and expand the first two dimensions to batch size and num_heads.
        #
        # You will the masking tensor to be on the same device as the attention scores's device,
        # which you can via the attribute `tensor.device`.

        mask=torch.triu(torch.ones((sequence_length,sequence_length),device=device),diagonal=1)
        mask = mask * -1e6
        return mask.unsqueeze(0).unsqueeze(0)



    def forward(self,
                hidden_states: torch.FloatTensor,
                key_padding_mask: torch.BoolTensor,
                encoder_outputs: Optional[torch.FloatTensor] = None) -> Tuple[torch.FloatTensor, torch.FloatTensor]:
        """Computes scaled dot-product attention and returns the output of the attention layer.

        Args:
            hidden_states: Tensor of shape (batch_size, sequence_length, hidden_size) - the input vectors to the layer.
            key_padding_mask: Tensor of shape (batch_size, sequence_length) indicating which tokens are padding tokens.
                    A `True` entry means that this token should be ignored for the purpose of attention.
                    In the case of cross-attention, the tensor has shape (batch_size, encoder_sequence_length).
            encoder_outputs: Optional tensor of shape (batch_size, encoder_sequence_length, hidden_size).
                    The output vectors of the encoder and only passed if the layer performs cross-attention.

        Returns:
            A (layer_output, attention_weights) where layer_output is a tensor of shape (batch_size, sequence_length, hidden_size)
            and attention_weights are the normalized attention scores in the form of
            a tensor of shape (batch_size, num_attention_heads, number_of_query_tokens, number_of_key_tokens).
        """

        # TODO Implement the forward function.
        # IMPORTANT: For full credit, you should not use python loops. Furthermore,
        #            you are not allowed to use `nn.MultiheadAttention` or `nn.functional.scaled_dot_product_attention`!
        #
        # Hint 1: Use `torch.reshape` to add a new axis for the attention head,
        #         which will allow you to process all attention heads in parallel.
        #
        # Hint 2: You can use `torch.transpose` to swap the order of two axes,
        #         As the attention head dimension should be next to the batch size,
        #         see the shape of the output attention weights.
        #
        # Hint 3: `torch.bmm(matrix1, matrix2)` is useful for computing batched matrix multiplications
        #         If matrix1 has shape (B, M, N) and matrix2 has shape (B, N, P),
        #         it performs `B` matrix multiplications and outputs a tensor of shape (B, M, P).
        #         Alternatively, `torch.einsum` should be very useful.
        #         (We really encourage you to check out the documentation of `torch.einsum`,
        #         it can really make your life easier here.)

        batch_size, sequence_length, hidden_size = hidden_states.size()

        if self.is_cross_attention:
            # Cross-attention: keys and values come from the encoder outputs
            query = self.query_proj(hidden_states)
            key = self.key_proj(encoder_outputs)
            value = self.value_proj(encoder_outputs)
            key_padding_mask = key_padding_mask[:, :encoder_outputs.size(1)]
        else:
            # Self-attention: keys and values come from the hidden states
            query = self.query_proj(hidden_states)
            key = self.key_proj(hidden_states)
            value = self.value_proj(hidden_states)

        # Reshape to separate heads
        query = query.view(batch_size, sequence_length, self.num_attention_heads, self.head_dim).transpose(1, 2)
        key = key.view(batch_size, -1, self.num_attention_heads, self.head_dim).transpose(1, 2)
        value = value.view(batch_size, -1, self.num_attention_heads, self.head_dim).transpose(1, 2)

        # Scaled dot-product attention
        attn_scores = torch.einsum("bhqd, bhkd -> bhqk", query, key) / (self.head_dim ** 0.5)

        # Apply key padding mask
        attn_scores = attn_scores.masked_fill(key_padding_mask.unsqueeze(1).unsqueeze(2), float('-inf'))

        # Apply causal mask if needed
        if self.is_causal_attention:
            causal_mask = self.causal_attention_mask(sequence_length, device=hidden_states.device)
            attn_scores = attn_scores + causal_mask

        # Softmax to get attention weights
        attn_weights = torch.softmax(attn_scores, dim=-1)

        # Attention output
        attn_output = torch.einsum("bhqk, bhkd -> bhqd", attn_weights, value)

        # Combine heads
        attn_output = attn_output.transpose(1, 2).contiguous().view(batch_size, sequence_length, hidden_size)

        # Final linear projection
        output = self.out_proj(attn_output)

        return output, attn_weights

# %% [markdown]
# Before we move on to the other modules, you should implement a sanity check for your attention implementation:
# 1. We check the dimensions of the output of the layer and
# 2. We plot the attention weights to some toy embedding inputs.
# We assume that the last token in the encoder and the last two tokens in the decoder are pad tokens.

# %%
embed_dim = 8
num_heads = 2
batch_size = 1
encoder_seq_length = 5
decoder_seq_length = 7

encoder_outputs = torch.randn(batch_size, encoder_seq_length, embed_dim)
decoder_inputs = torch.randn(batch_size, decoder_seq_length, embed_dim)

encoder_padding_mask = torch.zeros(batch_size, encoder_seq_length, dtype=torch.bool)
encoder_padding_mask[:, -1] = True # The last encoder token is a padding tokens

decoder_padding_mask = torch.zeros(batch_size, decoder_seq_length, dtype=torch.bool)
decoder_padding_mask[:, -2:] = True # The last two decoder tokens are padding token


cross_attention = MultiHeadAttention(embed_dim, num_heads, is_cross_attention=True)
causal_attention = MultiHeadAttention(embed_dim, num_heads, is_causal_attention=True)

cross_attention_out, cross_attention_weights = cross_attention(decoder_inputs, encoder_padding_mask, encoder_outputs)
causal_attention_out, causal_attention_weights = causal_attention(decoder_inputs, decoder_padding_mask)

# Make sure your outputs have the right hapes
assert cross_attention_out.shape == (batch_size, decoder_seq_length, embed_dim)
assert cross_attention_weights.shape == (batch_size, num_heads, decoder_seq_length, encoder_seq_length)
assert causal_attention_out.shape == (batch_size, decoder_seq_length, embed_dim)
assert causal_attention_weights.shape == (batch_size, num_heads, decoder_seq_length, decoder_seq_length)

# Check that the attention weights are normalized
assert torch.isclose(cross_attention_weights.sum(dim=-1), torch.tensor(1.0)).all()
assert torch.isclose(causal_attention_weights.sum(dim=-1), torch.tensor(1.0)).all()

# Check if the attention masking works
assert torch.isclose(cross_attention_weights[:,:,:,-1], torch.tensor(0.0)).all()
assert torch.isclose(causal_attention_weights[:,:,:,-2:], torch.tensor(0.0)).all()
assert torch.isclose(causal_attention_weights[:,:,2,3:], torch.tensor(0.0)).all()


import matplotlib.pyplot as plt

def plot_attention_matrix(attention_matrix, title):
    """Creates a new figure and plots the normalized attention weights as a heatmap.

    This should provide a colorbar for the scale of the heatmap and label the axes "query token position" and "key token position".
    Args:
        attention_matrix: A numpy array of shape (number_of_query_tokens, number_of_key_tokens)
        title: The title of the plot.
    """
    # TODO Implement this function
    plt.figure(figsize=(8, 6))
    plt.imshow(attention_matrix, aspect='auto', cmap='viridis')
    plt.colorbar()
    plt.title(title)
    plt.xlabel("Key token position")
    plt.ylabel("Query token position")
    plt.show()


plot_attention_matrix(cross_attention_weights[0,0].detach().numpy(), "cross-attention, head 1")
plot_attention_matrix(cross_attention_weights[0,1].detach().numpy(), "cross-attention, head 2")
plot_attention_matrix(causal_attention_weights[0,0].detach().numpy(), "causal self-attention, head 1")
plot_attention_matrix(causal_attention_weights[0,1].detach().numpy(), "causal self-attention, head 2")

# %%
class TransformerEmbeddings(nn.Module):
    def __init__(self, vocab_size: int, hidden_size: int, max_sequence_length: int):
        """Defines the embedding layer with learnt positional embeddings.

        This layer defines both the token embeddings and positional embeddings,
        which are added together to form the final embedding.

        Args:
            vocab_size: The size of the vocabulary,
                    used to define the size of the token embedding table.
            hidden_size: The dimensionality of the embedding space for both token embeddings and positional embeddings.
            max_sequence_length: The maximum sequence length of the input sequences,
                    used to define the size of the position embedding table.

        Note that this implementation does not use dropout on the embeddings
        and uses learnt positional embeddings instead of sinusoidal embeddings.
        """
        super().__init__()

        # TODO Initialize the module and its parameters here.
        # You should use `nn.Embedding` for both token embeddings and positional embeddings
        self.token_embeddings = nn.Embedding(vocab_size, hidden_size)
        self.position_embeddings = nn.Embedding(max_sequence_length, hidden_size)
        self.max_sequence_length = max_sequence_length



    def compute_logits(self, decoder_output: torch.FloatTensor) -> torch.FloatTensor:
        """Computes the logits for the next token prediction given the decoder output.

        Args:
            decoder_output: Tensor of shape (batch_size, sequence_length, hidden_size) - the output of the decoder.

        Returns:
            Tensor of shape (batch_size, sequence_length, vocab_size) containing the logits for the next token prediction.
        """

        # TODO Implement this function
        # Hint: you can access the weight parameter matrix via .weight of an nn.Embedding module:
        # Example:
        # ```embeddings = nn.Embedding(num_embeddings, embedding_dim)
        # assert list(embeddings.weight.shape) == [num_embeddings, embedding_dim]```
        # torch.matmul or F.linear may also be useful here.
        logits = torch.matmul(decoder_output, self.token_embeddings.weight.T)
        return logits


    def forward(self, input_ids: torch.LongTensor) -> torch.FloatTensor:
        """Computes the embeddings for the input tokens.

        Args:
            input_ids: Tensor of shape (batch_size, sequence_length) containing the input token ids.

        Returns:
            Tensor of shape (batch_size, sequence_length, hidden_size) containing
                    the sum of token embeddings and position embeddings for the input tokens.
        """

        # TODO Implement the forward pass of the embedding layer.
        # IMPORTANT: For full credit, you should not use python loops!

        batch_size, sequence_length = input_ids.size()

        # Create position ids from 0 to sequence_length - 1
        position_ids = torch.arange(sequence_length, dtype=torch.long, device=input_ids.device)
        position_ids = position_ids.unsqueeze(0).expand(batch_size, sequence_length)

        # Get token and position embeddings
        token_embeds = self.token_embeddings(input_ids)
        position_embeds = self.position_embeddings(position_ids)

        # Sum the token and position embeddings
        embeddings = token_embeds + position_embeds
        return embeddings

# %%
class TransformerBlock(nn.Module):
    def __init__(self,
                 hidden_size: int,
                 intermediate_size: int,
                 num_attention_heads: int,
                 hidden_dropout_prob: float,
                 is_decoder: bool = False):
        """Defines a single Transformer block, which can be either for the encoder or the decoder.

        Args:
            hidden_size: The dimensionality of the input and output vectors of this layer.
            intermediate_size: The intermediate size of the feedforward layers.
            num_attention_heads: The number of attention heads.
            hidden_dropout_prob: The dropout probability for the hidden states.
            is_decoder: Whether this block is part of the decoder.
        """
        super().__init__()

        self.is_decoder = is_decoder
        self.self_attention = MultiHeadAttention(hidden_size, num_attention_heads, is_causal_attention=is_decoder)
        self.self_attention_layer_norm = nn.LayerNorm(hidden_size)

        if is_decoder:
            self.cross_attention = MultiHeadAttention(hidden_size, num_attention_heads, is_cross_attention=True)
            self.cross_attention_layer_norm = nn.LayerNorm(hidden_size)

        self.feedforward = nn.Sequential(
            nn.Linear(hidden_size, intermediate_size),
            nn.ReLU(),
            nn.Linear(intermediate_size, hidden_size),
            nn.Dropout(hidden_dropout_prob))
        self.feedforward_layer_norm = nn.LayerNorm(hidden_size)

    def forward(self,
                hidden_states: torch.FloatTensor,
                padding_mask: torch.BoolTensor,
                encoder_outputs: Optional[torch.FloatTensor] = None,
                encoder_padding_mask: Optional[torch.BoolTensor] = None) -> torch.FloatTensor:
        """Defines a single Transformer block, either for the encoder or the decoder.

        Args:
            hidden_states: Tensor of shape (batch_size, sequence_length, hidden_size) - the outputs from the previous layer.
            padding_mask: Tensor of shape (batch_size, sequence_length) indicating which tokens are padding tokens.
                    A `True` entry means that this token should be ignored for the purpose of attention.
            encoder_outputs: Optional tensor of shape (batch_size, encoder_sequence_length, hidden_size),
                    which are the output vectors of the encoder. This argument is only used by decoder blocks.
            encoder_padding_mask: Optional tensor of shape (batch_size, encoder_sequence_length) indicating
                    which encoder tokens are padding tokens. This argument is only used in decoder blocks.
                    A `True` entry means that this token should be ignored for the purpose of attention.

        """
        hidden_states = self.self_attention(hidden_states, padding_mask)[0] + hidden_states
        hidden_states = self.self_attention_layer_norm(hidden_states)

        if self.is_decoder:
            hidden_states = self.cross_attention(hidden_states, encoder_padding_mask, encoder_outputs)[0] + hidden_states
            hidden_states = self.cross_attention_layer_norm(hidden_states)

        hidden_states = self.feedforward(hidden_states) + hidden_states
        hidden_states = self.feedforward_layer_norm(hidden_states)
        return hidden_states

# %%
class EncoderDecoderModel(nn.Module):
    def __init__(self,
                 source_vocab_size: int,
                 target_vocab_size: int,
                 hidden_size: int,
                 intermediate_size: int,
                 num_attention_heads: int,
                 num_encoder_layers: int,
                 num_decoder_layers: int,
                 max_sequence_length: int,
                 hidden_dropout_prob: float):
        """A encoder-decoder transformer model which can be used for NMT.

        Args:
            source_vocab_size: The size of the source vocabulary.
            target_vocab_size: The size of the target vocabulary.
            hidden_size: The dimensionality of all input and output embeddings.
            intermediate_size: The intermediate size in the feedforward layers.
            num_attention_heads: The number of attention heads in each multi-head attention modules.
            num_encoder_layers: The number of transformer blocks in the encoder.
            num_decoder_layers: The number of transformer blocks in the decoder.
            max_sequence_length: The maximum sequence length that this model can handle.
            hidden_dropout_prob: The dropout probability in the hidden state in each block.
        """

        super().__init__()

        self.source_embeddings = TransformerEmbeddings(source_vocab_size, hidden_size, max_sequence_length)
        self.target_embeddings = TransformerEmbeddings(target_vocab_size, hidden_size, max_sequence_length)

        # Define encoder blocks
        self.encoder = nn.ModuleList([
            TransformerBlock(hidden_size, intermediate_size, num_attention_heads, hidden_dropout_prob)
            for _ in range(num_encoder_layers)
        ])

        # Define decoder blocks
        self.decoder = nn.ModuleList([
            TransformerBlock(hidden_size, intermediate_size, num_attention_heads, hidden_dropout_prob, is_decoder=True)
            for _ in range(num_decoder_layers)
        ])

        # Define output projection layer
        self.output_projection = nn.Linear(hidden_size, target_vocab_size)

    def forward_encoder(self, input_ids: torch.LongTensor, padding_mask: torch.BoolTensor) -> torch.FloatTensor:
        """Implement the forward pass of the encoder.

        Args:
            input_ids: tensor of shape (batch_size, sequence_length) containing the input token ids to the encoder.
            padding_mask: tensor of shape (batch_size, sequence_length) indicating which encoder tokens are padding tokens (`True`)
                    and should be ignored in self-attention computations.

        Returns:
            Tensor of shape (batch_size, sequence_length, hidden_size) containing the output embeddings of the encoder.
        """

        source_embeddings = self.source_embeddings(input_ids)

        # Forward pass through encoder blocks
        encoder_hidden_states = source_embeddings
        for encoder_block in self.encoder:
            encoder_hidden_states = encoder_block(encoder_hidden_states, padding_mask)

        return encoder_hidden_states

    def forward_decoder(self,
                        input_ids: torch.LongTensor,
                        padding_mask: torch.BoolTensor,
                        encoder_outputs: torch.FloatTensor,
                        encoder_padding_mask: torch.BoolTensor) -> torch.FloatTensor:
        """Implement the forward pass of the decoder.

        Args:
            input_ids: Tensor of shape (batch_size, sequence_length) containing the input token ids to the decoder.
            padding_mask: Tensor of shape (batch_size, sequence_length) indicating which decoder tokens are padding tokens (`True`)
                    and should be ignored in self-attention computations.
            encoder_outputs: Tensor of shape (batch_size, encoder_sequence_length, hidden_size) containing the output embeddings of the encoder.
            encoder_padding_mask: Tensor of shape (batch_size, encoder_sequence_length) indicating which encoder tokens are padding tokens (`True`)
                    and should be ignored in cross-attention computations.

        Returns:
            Tensor of shape (batch_size, sequence_length, target_vocabulary_size)
            containing the logits for predicting the next token in the target sequence.
        """

        target_embeddings = self.target_embeddings(input_ids)

        # Forward pass through decoder blocks
        decoder_hidden_states = target_embeddings
        for decoder_block in self.decoder:
            decoder_hidden_states = decoder_block(decoder_hidden_states, padding_mask, encoder_outputs, encoder_padding_mask)

        # Project to target vocabulary size
        decoder_logits = self.output_projection(decoder_hidden_states)

        return decoder_logits

    def forward(self, encoder_input_ids, encoder_padding_mask, decoder_input_ids, decoder_padding_mask):
        encoder_outputs = self.forward_encoder(encoder_input_ids, encoder_padding_mask)
        decoder_logits = self.forward_decoder(decoder_input_ids, decoder_padding_mask, encoder_outputs, encoder_padding_mask)
        return decoder_logits

# %% [markdown]
# ## Train the model
#
# In this section, we train the seq2seq model on the parallel tokenized corpus.
# Before you start training models, you should implement and test the model and its sub-modules, especially the attention.
#
# First, we implement a `collate` function, which takes a list of examples from the dataset and forms a batch,
# consisting of padded encoder and decoder input ids, as well as encoder and decoder padding masks.

# %%
def collate_fn(examples: List[Dict[str, List[int]]]) -> Dict[str, torch.Tensor]:
    """Collates a list of variable length sequences from the dataset into a batch of pytorch tensors with padding."""

    encoder_sequence_length = max(len(example["encoder_input_ids"]) for example in examples)
    decoder_sequence_length = max(len(example["decoder_input_ids"]) for example in examples)
    batch_size = len(examples)

    encoder_input_ids = torch.full((batch_size, encoder_sequence_length),
                                   fill_value=source_tokenizer.pad_token_id,
                                   dtype=torch.int64)
    encoder_padding_mask = torch.ones((batch_size, encoder_sequence_length),
                                      dtype=torch.bool)

    decoder_input_ids = torch.full((batch_size, decoder_sequence_length),
                                   fill_value=target_tokenizer.pad_token_id,
                                   dtype=torch.int64)
    decoder_padding_mask = torch.ones((batch_size, decoder_sequence_length),
                                      dtype=torch.bool)

    for i, example in enumerate(examples):
        encoder_input_ids[i, :len(example["encoder_input_ids"])] = torch.tensor(example["encoder_input_ids"])
        encoder_padding_mask[i, :len(example["encoder_input_ids"])] = False

        decoder_input_ids[i, :len(example["decoder_input_ids"])] = torch.tensor(example["decoder_input_ids"])
        decoder_padding_mask[i, :len(example["decoder_input_ids"])] = False

    return {"encoder_input_ids": encoder_input_ids,
            "encoder_padding_mask": encoder_padding_mask,
            "decoder_input_ids": decoder_input_ids,
            "decoder_padding_mask": decoder_padding_mask}

# %% [markdown]
# Next, we provide a simple training loop.

# %%
import time
import math

def compute_loss_per_token(model, batch):
    logits = model(**batch)

    valid_label_mask = ~(batch["decoder_padding_mask"][:,1:])
    labels = batch["decoder_input_ids"][:,1:][valid_label_mask]
    logits = logits[:,:-1][valid_label_mask]

    return F.cross_entropy(logits, labels, reduction='none')


def evaluate_perplexity(model, dataset, batch_size=32, device="cpu"):
    model.eval()

    dev_loader = torch.utils.data.DataLoader(
        dataset, batch_size=batch_size, shuffle=False, collate_fn=collate_fn)

    num_tokens = loss_sum = 0

    # no_grad() signals backend to throw away all gradients
    with torch.no_grad():
        for batch in dev_loader:
            # Move tensors in batch to device
            for key in batch:
                batch[key] = batch[key].to(device)

            token_losses = compute_loss_per_token(model, batch)

            loss_sum += token_losses.sum()
            num_tokens += token_losses.numel()

        dev_ppl = (loss_sum / num_tokens).exp().cpu().item()
    return dev_ppl


def train(model, training_dataset, validation_dataset,
          batch_size=32, lr=1e-3, max_epoch=15, log_every=10, valid_niter=100,
          model_path="model.pt"):
    model.train()

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print('Use device: %s' % device)

    model = model.to(device)

    optimizer = torch.optim.Adam(model.parameters(), lr=lr)

    epoch = global_step = loss_sum = num_tokens = num_examples = 0
    best_valid_perplexity = float('inf')
    train_time = begin_time = time.time()
    print('Beginning maximum likelihood training')


    while True:
        train_loader = torch.utils.data.DataLoader(
            training_dataset, batch_size=batch_size, shuffle=True, collate_fn=collate_fn)
        epoch += 1
        batches_per_epoch = len(train_loader)
        for i, batch in enumerate(train_loader):
            global_step += 1

            # Move tensors in batch to device
            for key in batch:
                batch[key] = batch[key].to(device)

            optimizer.zero_grad()

            token_losses = compute_loss_per_token(model, batch)
            total_loss = token_losses.sum()

            loss = total_loss / batch_size
            loss.backward()

            optimizer.step()

            loss_sum += total_loss.cpu().item()
            num_tokens += token_losses.numel()
            num_examples += batch_size

            if global_step % log_every == 0:
                average_loss = loss_sum / num_examples
                average_ppl = math.exp(loss_sum / num_tokens)
                print(f"epoch {epoch} ({i}/{batches_per_epoch}) | step {global_step} | "
                      f"avg_nll={average_loss:.2f} avg_ppl={average_ppl:.2f} "
                      f"speed={num_tokens / (time.time() - train_time):.2f} words/sec "
                      f"time_elapsed={time.time() - begin_time:.2f} sec")

                train_time = time.time()
                loss_sum = num_tokens = num_examples = 0.0

            if global_step % valid_niter == 0:
                print('Begin validation ...')
                dev_perplexity = evaluate_perplexity(model, validation_dataset, batch_size=batch_size, device=device)

                print(f"validation: step {global_step} | dev_ppl={dev_perplexity}")

                if dev_perplexity < best_valid_perplexity:
                    best_valid_perplexity = dev_perplexity
                    print(f"epoch {epoch} step {global_step}: save currently the best model to '{model_path}'")
                    torch.save(model.state_dict(), model_path)
                    torch.save(optimizer.state_dict(), model_path + '.optim')
                model.train()

        if epoch == max_epoch:
            print('Reached maximum number of epochs')
            break

# %% [markdown]
# Let's train a relatively small model architecture for 15 epochs.
# With a reasonable implementation, this should take about 16 minutes on CPU / 3 minutes on GPU and we should achieve a validation perplexity of below 10!

# %%
# Set a random seed, so you obtain the same output model if you run this cell again.
seed = 42
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)

model = EncoderDecoderModel(
    source_vocab_size=source_tokenizer.vocab_size,
    target_vocab_size=target_tokenizer.vocab_size,
    hidden_size=128,
    intermediate_size=128 * 4,
    num_attention_heads=16,
    num_encoder_layers=6,
    num_decoder_layers=6,
    max_sequence_length=32,
    hidden_dropout_prob=0.3,
    )

print("Model architecture:", model)
print("Total number of trainable model parameters:", sum(p.numel() for p in model.parameters() if p.requires_grad))

train(model, tokenized_datasets["train"], tokenized_datasets["validation"],
      max_epoch=22, model_path="model.pt")
# Out:
# Model architecture: EncoderDecoderModel(
#   (source_embeddings): TransformerEmbeddings(
#     (token_embeddings): Embedding(3200, 128)
#     (position_embeddings): Embedding(32, 128)
#   )
#   (target_embeddings): TransformerEmbeddings(
#     (token_embeddings): Embedding(3200, 128)
#     (position_embeddings): Embedding(32, 128)
#   )
#   (encoder): ModuleList(
#     (0-5): 6 x TransformerBlock(
#       (self_attention): MultiHeadAttention(
#         (query_proj): Linear(in_features=128, out_features=128, bias=True)
#         (key_proj): Linear(in_features=128, out_features=128, bias=True)
#         (value_proj): Linear(in_features=128, out_features=128, bias=True)
#         (out_proj): Linear(in_features=128, out_features=128, bias=True)
#       )
#       (self_attention_layer_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#       (feedforward): Sequential(
#         (0): Linear(in_features=128, out_features=512, bias=True)
#         (1): ReLU()
#         (2): Linear(in_features=512, out_features=128, bias=True)
#         (3): Dropout(p=0.3, inplace=False)
#       )
#       (feedforward_layer_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#     )
#   )
#   (decoder): ModuleList(
#     (0-5): 6 x TransformerBlock(
#       (self_attention): MultiHeadAttention(
#         (query_proj): Linear(in_features=128, out_features=128, bias=True)
#         (key_proj): Linear(in_features=128, out_features=128, bias=True)
#         (value_proj): Linear(in_features=128, out_features=128, bias=True)
#         (out_proj): Linear(in_features=128, out_features=128, bias=True)
#       )
#       (self_attention_layer_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#       (cross_attention): MultiHeadAttention(
#         (query_proj): Linear(in_features=128, out_features=128, bias=True)
#         (key_proj): Linear(in_features=128, out_features=128, bias=True)
#         (value_proj): Linear(in_features=128, out_features=128, bias=True)
#         (out_proj): Linear(in_features=128, out_features=128, bias=True)
#       )
#       (cross_attention_layer_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#       (feedforward): Sequential(
#         (0): Linear(in_features=128, out_features=512, bias=True)
#         (1): ReLU()
#         (2): Linear(in_features=512, out_features=128, bias=True)
#         (3): Dropout(p=0.3, inplace=False)
#       )
#       (feedforward_layer_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#     )
#   )
#   (output_projection): Linear(in_features=128, out_features=3200, bias=True)
# )
# Total number of trainable model parameters: 4017280
# Use device: cuda
# Beginning maximum likelihood training
# epoch 1 (9/272) | step 10 | avg_nll=43.31 avg_ppl=462.76 speed=955.44 words/sec time_elapsed=2.36 sec
# epoch 1 (19/272) | step 20 | avg_nll=33.62 avg_ppl=106.18 speed=3093.92 words/sec time_elapsed=3.11 sec
# epoch 1 (29/272) | step 30 | avg_nll=30.04 avg_ppl=55.85 speed=3318.11 words/sec time_elapsed=3.83 sec
# epoch 1 (39/272) | step 40 | avg_nll=26.46 avg_ppl=38.02 speed=2137.02 words/sec time_elapsed=4.92 sec
# epoch 1 (49/272) | step 50 | avg_nll=25.42 avg_ppl=34.61 speed=1627.20 words/sec time_elapsed=6.33 sec
# epoch 1 (59/272) | step 60 | avg_nll=24.09 avg_ppl=28.03 speed=1518.75 words/sec time_elapsed=7.85 sec
# epoch 1 (69/272) | step 70 | avg_nll=23.45 avg_ppl=25.64 speed=1568.54 words/sec time_elapsed=9.33 sec
# epoch 1 (79/272) | step 80 | avg_nll=23.14 avg_ppl=23.93 speed=2776.85 words/sec time_elapsed=10.17 sec
# epoch 1 (89/272) | step 90 | avg_nll=22.27 avg_ppl=21.70 speed=1554.18 words/sec time_elapsed=11.66 sec
# epoch 1 (99/272) | step 100 | avg_nll=21.56 avg_ppl=19.72 speed=1815.81 words/sec time_elapsed=12.94 sec
# Begin validation ...
# validation: step 100 | dev_ppl=18.391921997070312
# epoch 1 step 100: save currently the best model to 'model.pt'
# epoch 1 (109/272) | step 110 | avg_nll=21.76 avg_ppl=19.89 speed=901.09 words/sec time_elapsed=15.54 sec
# epoch 1 (119/272) | step 120 | avg_nll=21.85 avg_ppl=20.25 speed=2559.55 words/sec time_elapsed=16.45 sec
# epoch 1 (129/272) | step 130 | avg_nll=21.37 avg_ppl=19.62 speed=2673.88 words/sec time_elapsed=17.31 sec
# epoch 1 (139/272) | step 140 | avg_nll=20.58 avg_ppl=16.92 speed=2540.85 words/sec time_elapsed=18.22 sec
# epoch 1 (149/272) | step 150 | avg_nll=20.77 avg_ppl=17.24 speed=2062.44 words/sec time_elapsed=19.36 sec
# epoch 1 (159/272) | step 160 | avg_nll=21.15 avg_ppl=17.77 speed=1390.51 words/sec time_elapsed=21.05 sec
# epoch 1 (169/272) | step 170 | avg_nll=21.09 avg_ppl=17.84 speed=1961.23 words/sec time_elapsed=22.25 sec
# epoch 1 (179/272) | step 180 | avg_nll=20.34 avg_ppl=16.77 speed=2614.74 words/sec time_elapsed=23.13 sec
# epoch 1 (189/272) | step 190 | avg_nll=18.89 avg_ppl=14.04 speed=2584.07 words/sec time_elapsed=24.02 sec
# epoch 1 (199/272) | step 200 | avg_nll=19.67 avg_ppl=15.35 speed=3199.40 words/sec time_elapsed=24.74 sec
# Begin validation ...
# validation: step 200 | dev_ppl=13.70777416229248
# epoch 1 step 200: save currently the best model to 'model.pt'
# epoch 1 (209/272) | step 210 | avg_nll=19.59 avg_ppl=14.95 speed=1581.42 words/sec time_elapsed=26.21 sec
# epoch 1 (219/272) | step 220 | avg_nll=19.42 avg_ppl=14.56 speed=2303.43 words/sec time_elapsed=27.22 sec
# epoch 1 (229/272) | step 230 | avg_nll=19.58 avg_ppl=14.81 speed=2376.04 words/sec time_elapsed=28.20 sec
# epoch 1 (239/272) | step 240 | avg_nll=19.74 avg_ppl=15.03 speed=2488.92 words/sec time_elapsed=29.13 sec
# epoch 1 (249/272) | step 250 | avg_nll=18.90 avg_ppl=13.72 speed=5104.22 words/sec time_elapsed=29.58 sec
# epoch 1 (259/272) | step 260 | avg_nll=17.82 avg_ppl=12.35 speed=4788.70 words/sec time_elapsed=30.06 sec
# epoch 1 (269/272) | step 270 | avg_nll=18.40 avg_ppl=12.60 speed=5133.93 words/sec time_elapsed=30.51 sec
# epoch 2 (7/272) | step 280 | avg_nll=18.37 avg_ppl=12.63 speed=4932.98 words/sec time_elapsed=30.98 sec
# epoch 2 (17/272) | step 290 | avg_nll=16.69 avg_ppl=10.18 speed=4942.56 words/sec time_elapsed=31.45 sec
# epoch 2 (27/272) | step 300 | avg_nll=16.63 avg_ppl=10.17 speed=5026.48 words/sec time_elapsed=31.90 sec
# Begin validation ...
# validation: step 300 | dev_ppl=11.11639404296875
# epoch 2 step 300: save currently the best model to 'model.pt'
# epoch 2 (37/272) | step 310 | avg_nll=17.33 avg_ppl=10.81 speed=2192.95 words/sec time_elapsed=32.97 sec
# epoch 2 (47/272) | step 320 | avg_nll=16.33 avg_ppl=10.00 speed=3657.84 words/sec time_elapsed=33.59 sec
# epoch 2 (57/272) | step 330 | avg_nll=16.86 avg_ppl=10.24 speed=3344.80 words/sec time_elapsed=34.28 sec
# epoch 2 (67/272) | step 340 | avg_nll=16.71 avg_ppl=10.21 speed=3305.68 words/sec time_elapsed=34.98 sec
# epoch 2 (77/272) | step 350 | avg_nll=16.66 avg_ppl=10.22 speed=3892.00 words/sec time_elapsed=35.57 sec
# epoch 2 (87/272) | step 360 | avg_nll=16.59 avg_ppl=10.05 speed=5029.92 words/sec time_elapsed=36.03 sec
# epoch 2 (97/272) | step 370 | avg_nll=16.27 avg_ppl=9.52 speed=4974.04 words/sec time_elapsed=36.49 sec
# epoch 2 (107/272) | step 380 | avg_nll=16.54 avg_ppl=9.52 speed=5068.35 words/sec time_elapsed=36.95 sec
# epoch 2 (117/272) | step 390 | avg_nll=16.28 avg_ppl=9.44 speed=4981.57 words/sec time_elapsed=37.42 sec
# epoch 2 (127/272) | step 400 | avg_nll=16.08 avg_ppl=9.00 speed=5107.74 words/sec time_elapsed=37.88 sec
# Begin validation ...
# validation: step 400 | dev_ppl=9.137892723083496
# epoch 2 step 400: save currently the best model to 'model.pt'
# epoch 2 (137/272) | step 410 | avg_nll=16.44 avg_ppl=9.60 speed=2531.88 words/sec time_elapsed=38.80 sec
# epoch 2 (147/272) | step 420 | avg_nll=15.71 avg_ppl=8.46 speed=5105.06 words/sec time_elapsed=39.26 sec
# epoch 2 (157/272) | step 430 | avg_nll=16.56 avg_ppl=9.60 speed=4808.68 words/sec time_elapsed=39.75 sec
# epoch 2 (167/272) | step 440 | avg_nll=16.10 avg_ppl=9.06 speed=5101.43 words/sec time_elapsed=40.20 sec
# epoch 2 (177/272) | step 450 | avg_nll=16.52 avg_ppl=9.62 speed=4905.82 words/sec time_elapsed=40.68 sec
# epoch 2 (187/272) | step 460 | avg_nll=15.79 avg_ppl=8.46 speed=5105.23 words/sec time_elapsed=41.14 sec
# epoch 2 (197/272) | step 470 | avg_nll=16.34 avg_ppl=9.15 speed=5069.10 words/sec time_elapsed=41.61 sec
# epoch 2 (207/272) | step 480 | avg_nll=15.56 avg_ppl=8.72 speed=5070.97 words/sec time_elapsed=42.06 sec
# epoch 2 (217/272) | step 490 | avg_nll=14.19 avg_ppl=7.48 speed=4510.79 words/sec time_elapsed=42.56 sec
# epoch 2 (227/272) | step 500 | avg_nll=14.61 avg_ppl=7.58 speed=4890.41 words/sec time_elapsed=43.03 sec
# Begin validation ...
# validation: step 500 | dev_ppl=7.910055160522461
# epoch 2 step 500: save currently the best model to 'model.pt'
# epoch 2 (237/272) | step 510 | avg_nll=14.71 avg_ppl=7.93 speed=2561.60 words/sec time_elapsed=43.92 sec
# epoch 2 (247/272) | step 520 | avg_nll=15.97 avg_ppl=8.75 speed=5146.39 words/sec time_elapsed=44.38 sec
# epoch 2 (257/272) | step 530 | avg_nll=14.17 avg_ppl=7.33 speed=4864.98 words/sec time_elapsed=44.85 sec
# epoch 2 (267/272) | step 540 | avg_nll=14.21 avg_ppl=7.15 speed=5058.09 words/sec time_elapsed=45.31 sec
# epoch 3 (5/272) | step 550 | avg_nll=14.44 avg_ppl=7.28 speed=3381.79 words/sec time_elapsed=45.99 sec
# epoch 3 (15/272) | step 560 | avg_nll=13.02 avg_ppl=6.11 speed=3653.01 words/sec time_elapsed=46.62 sec
# epoch 3 (25/272) | step 570 | avg_nll=12.96 avg_ppl=5.87 speed=3269.72 words/sec time_elapsed=47.34 sec
# epoch 3 (35/272) | step 580 | avg_nll=12.41 avg_ppl=5.64 speed=3304.84 words/sec time_elapsed=48.04 sec
# epoch 3 (45/272) | step 590 | avg_nll=12.44 avg_ppl=5.58 speed=5067.28 words/sec time_elapsed=48.49 sec
# epoch 3 (55/272) | step 600 | avg_nll=14.33 avg_ppl=6.84 speed=4913.41 words/sec time_elapsed=48.98 sec
# Begin validation ...
# validation: step 600 | dev_ppl=6.969010829925537
# epoch 3 step 600: save currently the best model to 'model.pt'
# epoch 3 (65/272) | step 610 | avg_nll=12.43 avg_ppl=5.49 speed=2568.31 words/sec time_elapsed=49.89 sec
# epoch 3 (75/272) | step 620 | avg_nll=12.93 avg_ppl=5.95 speed=4629.07 words/sec time_elapsed=50.39 sec
# epoch 3 (85/272) | step 630 | avg_nll=12.42 avg_ppl=5.52 speed=4896.00 words/sec time_elapsed=50.87 sec
# epoch 3 (95/272) | step 640 | avg_nll=13.27 avg_ppl=6.26 speed=4976.06 words/sec time_elapsed=51.33 sec
# epoch 3 (105/272) | step 650 | avg_nll=12.18 avg_ppl=5.38 speed=4862.75 words/sec time_elapsed=51.81 sec
# epoch 3 (115/272) | step 660 | avg_nll=13.00 avg_ppl=5.94 speed=5148.14 words/sec time_elapsed=52.26 sec
# epoch 3 (125/272) | step 670 | avg_nll=12.38 avg_ppl=5.64 speed=4862.08 words/sec time_elapsed=52.73 sec
# epoch 3 (135/272) | step 680 | avg_nll=13.25 avg_ppl=6.26 speed=5074.46 words/sec time_elapsed=53.19 sec
# epoch 3 (145/272) | step 690 | avg_nll=12.38 avg_ppl=5.59 speed=4986.85 words/sec time_elapsed=53.65 sec
# epoch 3 (155/272) | step 700 | avg_nll=11.88 avg_ppl=5.31 speed=4814.32 words/sec time_elapsed=54.12 sec
# Begin validation ...
# validation: step 700 | dev_ppl=6.261652946472168
# epoch 3 step 700: save currently the best model to 'model.pt'
# epoch 3 (165/272) | step 710 | avg_nll=12.32 avg_ppl=5.62 speed=2495.27 words/sec time_elapsed=55.04 sec
# epoch 3 (175/272) | step 720 | avg_nll=11.14 avg_ppl=4.73 speed=5207.05 words/sec time_elapsed=55.48 sec
# epoch 3 (185/272) | step 730 | avg_nll=13.05 avg_ppl=5.99 speed=5039.71 words/sec time_elapsed=55.94 sec
# epoch 3 (195/272) | step 740 | avg_nll=13.08 avg_ppl=5.96 speed=5136.49 words/sec time_elapsed=56.40 sec
# epoch 3 (205/272) | step 750 | avg_nll=12.49 avg_ppl=5.52 speed=4943.21 words/sec time_elapsed=56.87 sec
# epoch 3 (215/272) | step 760 | avg_nll=13.33 avg_ppl=6.16 speed=5143.15 words/sec time_elapsed=57.33 sec
# epoch 3 (225/272) | step 770 | avg_nll=12.43 avg_ppl=5.56 speed=4970.17 words/sec time_elapsed=57.79 sec
# epoch 3 (235/272) | step 780 | avg_nll=12.78 avg_ppl=5.82 speed=3805.35 words/sec time_elapsed=58.40 sec
# epoch 3 (245/272) | step 790 | avg_nll=11.84 avg_ppl=5.23 speed=3617.56 words/sec time_elapsed=59.04 sec
# epoch 3 (255/272) | step 800 | avg_nll=11.41 avg_ppl=4.86 speed=3457.13 words/sec time_elapsed=59.71 sec
# Begin validation ...
# validation: step 800 | dev_ppl=5.670709609985352
# epoch 3 step 800: save currently the best model to 'model.pt'
# epoch 3 (265/272) | step 810 | avg_nll=11.79 avg_ppl=5.27 speed=1947.14 words/sec time_elapsed=60.87 sec
# epoch 4 (3/272) | step 820 | avg_nll=11.24 avg_ppl=4.75 speed=4755.05 words/sec time_elapsed=61.36 sec
# epoch 4 (13/272) | step 830 | avg_nll=10.38 avg_ppl=4.11 speed=5071.44 words/sec time_elapsed=61.82 sec
# epoch 4 (23/272) | step 840 | avg_nll=10.35 avg_ppl=4.09 speed=5141.17 words/sec time_elapsed=62.28 sec
# epoch 4 (33/272) | step 850 | avg_nll=9.33 avg_ppl=3.57 speed=5111.02 words/sec time_elapsed=62.74 sec
# epoch 4 (43/272) | step 860 | avg_nll=9.82 avg_ppl=3.97 speed=4874.13 words/sec time_elapsed=63.20 sec
# epoch 4 (53/272) | step 870 | avg_nll=9.78 avg_ppl=3.88 speed=4999.26 words/sec time_elapsed=63.67 sec
# epoch 4 (63/272) | step 880 | avg_nll=9.94 avg_ppl=3.95 speed=5022.57 words/sec time_elapsed=64.13 sec
# epoch 4 (73/272) | step 890 | avg_nll=10.00 avg_ppl=3.98 speed=5160.16 words/sec time_elapsed=64.57 sec
# epoch 4 (83/272) | step 900 | avg_nll=9.81 avg_ppl=3.91 speed=4994.70 words/sec time_elapsed=65.04 sec
# Begin validation ...
# validation: step 900 | dev_ppl=5.144349575042725
# epoch 4 step 900: save currently the best model to 'model.pt'
# epoch 4 (93/272) | step 910 | avg_nll=10.26 avg_ppl=4.01 speed=2591.12 words/sec time_elapsed=65.95 sec
# epoch 4 (103/272) | step 920 | avg_nll=10.22 avg_ppl=4.12 speed=4969.40 words/sec time_elapsed=66.41 sec
# epoch 4 (113/272) | step 930 | avg_nll=9.63 avg_ppl=3.82 speed=5054.00 words/sec time_elapsed=66.87 sec
# epoch 4 (123/272) | step 940 | avg_nll=8.82 avg_ppl=3.47 speed=4867.35 words/sec time_elapsed=67.34 sec
# epoch 4 (133/272) | step 950 | avg_nll=10.20 avg_ppl=4.04 speed=5120.70 words/sec time_elapsed=67.79 sec
# epoch 4 (143/272) | step 960 | avg_nll=10.03 avg_ppl=3.93 speed=5043.30 words/sec time_elapsed=68.26 sec
# epoch 4 (153/272) | step 970 | avg_nll=10.23 avg_ppl=4.01 speed=5215.04 words/sec time_elapsed=68.71 sec
# epoch 4 (163/272) | step 980 | avg_nll=9.39 avg_ppl=3.64 speed=4885.90 words/sec time_elapsed=69.18 sec
# epoch 4 (173/272) | step 990 | avg_nll=9.45 avg_ppl=3.72 speed=5114.54 words/sec time_elapsed=69.64 sec
# epoch 4 (183/272) | step 1000 | avg_nll=9.98 avg_ppl=3.90 speed=4944.61 words/sec time_elapsed=70.11 sec
# Begin validation ...
# validation: step 1000 | dev_ppl=4.810189247131348
# epoch 4 step 1000: save currently the best model to 'model.pt'
# epoch 4 (193/272) | step 1010 | avg_nll=9.90 avg_ppl=3.96 speed=2021.88 words/sec time_elapsed=71.25 sec
# epoch 4 (203/272) | step 1020 | avg_nll=9.74 avg_ppl=3.83 speed=3590.99 words/sec time_elapsed=71.90 sec
# epoch 4 (213/272) | step 1030 | avg_nll=8.80 avg_ppl=3.47 speed=3149.25 words/sec time_elapsed=72.61 sec
# epoch 4 (223/272) | step 1040 | avg_nll=10.41 avg_ppl=4.13 speed=3606.91 words/sec time_elapsed=73.27 sec
# epoch 4 (233/272) | step 1050 | avg_nll=9.68 avg_ppl=3.73 speed=4995.68 words/sec time_elapsed=73.74 sec
# epoch 4 (243/272) | step 1060 | avg_nll=9.28 avg_ppl=3.67 speed=4826.41 words/sec time_elapsed=74.21 sec
# epoch 4 (253/272) | step 1070 | avg_nll=9.72 avg_ppl=3.87 speed=4924.66 words/sec time_elapsed=74.68 sec
# epoch 4 (263/272) | step 1080 | avg_nll=8.95 avg_ppl=3.49 speed=4943.29 words/sec time_elapsed=75.14 sec
# epoch 5 (1/272) | step 1090 | avg_nll=8.91 avg_ppl=3.47 speed=4840.92 words/sec time_elapsed=75.61 sec
# epoch 5 (11/272) | step 1100 | avg_nll=7.39 avg_ppl=2.74 speed=5105.43 words/sec time_elapsed=76.07 sec
# Begin validation ...
# validation: step 1100 | dev_ppl=4.4042558670043945
# epoch 5 step 1100: save currently the best model to 'model.pt'
# epoch 5 (21/272) | step 1110 | avg_nll=7.11 avg_ppl=2.73 speed=2498.54 words/sec time_elapsed=76.98 sec
# epoch 5 (31/272) | step 1120 | avg_nll=7.21 avg_ppl=2.71 speed=4977.92 words/sec time_elapsed=77.45 sec
# epoch 5 (41/272) | step 1130 | avg_nll=6.98 avg_ppl=2.61 speed=5084.62 words/sec time_elapsed=77.90 sec
# epoch 5 (51/272) | step 1140 | avg_nll=6.85 avg_ppl=2.57 speed=5028.94 words/sec time_elapsed=78.37 sec
# epoch 5 (61/272) | step 1150 | avg_nll=6.56 avg_ppl=2.47 speed=4812.79 words/sec time_elapsed=78.85 sec
# epoch 5 (71/272) | step 1160 | avg_nll=6.93 avg_ppl=2.64 speed=4839.30 words/sec time_elapsed=79.32 sec
# epoch 5 (81/272) | step 1170 | avg_nll=6.67 avg_ppl=2.51 speed=4823.35 words/sec time_elapsed=79.80 sec
# epoch 5 (91/272) | step 1180 | avg_nll=7.30 avg_ppl=2.71 speed=4822.06 words/sec time_elapsed=80.29 sec
# epoch 5 (101/272) | step 1190 | avg_nll=7.22 avg_ppl=2.71 speed=4892.82 words/sec time_elapsed=80.76 sec
# epoch 5 (111/272) | step 1200 | avg_nll=6.92 avg_ppl=2.60 speed=5016.22 words/sec time_elapsed=81.22 sec
# Begin validation ...
# validation: step 1200 | dev_ppl=4.222163200378418
# epoch 5 step 1200: save currently the best model to 'model.pt'
# epoch 5 (121/272) | step 1210 | avg_nll=7.17 avg_ppl=2.69 speed=2585.77 words/sec time_elapsed=82.12 sec
# epoch 5 (131/272) | step 1220 | avg_nll=6.78 avg_ppl=2.61 speed=4662.47 words/sec time_elapsed=82.60 sec
# epoch 5 (141/272) | step 1230 | avg_nll=7.60 avg_ppl=2.84 speed=5021.07 words/sec time_elapsed=83.07 sec
# epoch 5 (151/272) | step 1240 | avg_nll=7.83 avg_ppl=2.92 speed=3619.89 words/sec time_elapsed=83.71 sec
# epoch 5 (161/272) | step 1250 | avg_nll=6.98 avg_ppl=2.68 speed=3724.12 words/sec time_elapsed=84.32 sec
# epoch 5 (171/272) | step 1260 | avg_nll=7.45 avg_ppl=2.76 speed=3237.89 words/sec time_elapsed=85.05 sec
# epoch 5 (181/272) | step 1270 | avg_nll=7.89 avg_ppl=2.95 speed=3304.99 words/sec time_elapsed=85.76 sec
# epoch 5 (191/272) | step 1280 | avg_nll=7.72 avg_ppl=2.89 speed=4564.20 words/sec time_elapsed=86.27 sec
# epoch 5 (201/272) | step 1290 | avg_nll=7.50 avg_ppl=2.83 speed=4930.18 words/sec time_elapsed=86.74 sec
# epoch 5 (211/272) | step 1300 | avg_nll=7.39 avg_ppl=2.72 speed=5206.54 words/sec time_elapsed=87.19 sec
# Begin validation ...
# validation: step 1300 | dev_ppl=4.124976634979248
# epoch 5 step 1300: save currently the best model to 'model.pt'
# epoch 5 (221/272) | step 1310 | avg_nll=6.56 avg_ppl=2.51 speed=2547.53 words/sec time_elapsed=88.08 sec
# epoch 5 (231/272) | step 1320 | avg_nll=6.75 avg_ppl=2.57 speed=5137.12 words/sec time_elapsed=88.53 sec
# epoch 5 (241/272) | step 1330 | avg_nll=7.36 avg_ppl=2.76 speed=4908.45 words/sec time_elapsed=89.00 sec
# epoch 5 (251/272) | step 1340 | avg_nll=7.23 avg_ppl=2.70 speed=5100.80 words/sec time_elapsed=89.46 sec
# epoch 5 (261/272) | step 1350 | avg_nll=7.37 avg_ppl=2.75 speed=4914.76 words/sec time_elapsed=89.93 sec
# epoch 5 (271/272) | step 1360 | avg_nll=7.01 avg_ppl=2.61 speed=5119.01 words/sec time_elapsed=90.39 sec
# epoch 6 (9/272) | step 1370 | avg_nll=5.29 avg_ppl=2.07 speed=4871.85 words/sec time_elapsed=90.87 sec
# epoch 6 (19/272) | step 1380 | avg_nll=4.53 avg_ppl=1.89 speed=4916.51 words/sec time_elapsed=91.33 sec
# epoch 6 (29/272) | step 1390 | avg_nll=4.44 avg_ppl=1.86 speed=4786.32 words/sec time_elapsed=91.81 sec
# epoch 6 (39/272) | step 1400 | avg_nll=4.94 avg_ppl=1.96 speed=5046.13 words/sec time_elapsed=92.28 sec
# Begin validation ...
# validation: step 1400 | dev_ppl=3.9427661895751953
# epoch 6 step 1400: save currently the best model to 'model.pt'
# epoch 6 (49/272) | step 1410 | avg_nll=4.22 avg_ppl=1.81 speed=2424.03 words/sec time_elapsed=93.21 sec
# epoch 6 (59/272) | step 1420 | avg_nll=4.49 avg_ppl=1.87 speed=5063.27 words/sec time_elapsed=93.67 sec
# epoch 6 (69/272) | step 1430 | avg_nll=4.85 avg_ppl=1.98 speed=2963.71 words/sec time_elapsed=94.43 sec
# epoch 6 (79/272) | step 1440 | avg_nll=4.91 avg_ppl=1.95 speed=3054.50 words/sec time_elapsed=95.21 sec
# epoch 6 (89/272) | step 1450 | avg_nll=4.81 avg_ppl=1.94 speed=4929.12 words/sec time_elapsed=95.68 sec
# epoch 6 (99/272) | step 1460 | avg_nll=4.64 avg_ppl=1.88 speed=2334.90 words/sec time_elapsed=96.69 sec
# epoch 6 (109/272) | step 1470 | avg_nll=4.83 avg_ppl=1.96 speed=3578.73 words/sec time_elapsed=97.33 sec
# epoch 6 (119/272) | step 1480 | avg_nll=4.75 avg_ppl=1.92 speed=3307.24 words/sec time_elapsed=98.03 sec
# epoch 6 (129/272) | step 1490 | avg_nll=5.07 avg_ppl=2.01 speed=3315.55 words/sec time_elapsed=98.73 sec
# epoch 6 (139/272) | step 1500 | avg_nll=4.81 avg_ppl=1.94 speed=4722.08 words/sec time_elapsed=99.23 sec
# Begin validation ...
# validation: step 1500 | dev_ppl=3.930870532989502
# epoch 6 step 1500: save currently the best model to 'model.pt'
# epoch 6 (149/272) | step 1510 | avg_nll=5.16 avg_ppl=2.03 speed=2575.57 words/sec time_elapsed=100.13 sec
# epoch 6 (159/272) | step 1520 | avg_nll=4.83 avg_ppl=1.94 speed=5058.21 words/sec time_elapsed=100.59 sec
# epoch 6 (169/272) | step 1530 | avg_nll=4.76 avg_ppl=1.93 speed=4616.12 words/sec time_elapsed=101.09 sec
# epoch 6 (179/272) | step 1540 | avg_nll=5.03 avg_ppl=2.01 speed=4942.21 words/sec time_elapsed=101.56 sec
# epoch 6 (189/272) | step 1550 | avg_nll=5.54 avg_ppl=2.15 speed=5116.02 words/sec time_elapsed=102.01 sec
# epoch 6 (199/272) | step 1560 | avg_nll=5.56 avg_ppl=2.14 speed=5082.64 words/sec time_elapsed=102.47 sec
# epoch 6 (209/272) | step 1570 | avg_nll=5.53 avg_ppl=2.16 speed=4868.23 words/sec time_elapsed=102.94 sec
# epoch 6 (219/272) | step 1580 | avg_nll=5.34 avg_ppl=2.11 speed=4862.50 words/sec time_elapsed=103.42 sec
# epoch 6 (229/272) | step 1590 | avg_nll=5.80 avg_ppl=2.22 speed=5024.77 words/sec time_elapsed=103.88 sec
# epoch 6 (239/272) | step 1600 | avg_nll=6.23 avg_ppl=2.34 speed=4966.86 words/sec time_elapsed=104.35 sec
# Begin validation ...
# validation: step 1600 | dev_ppl=3.9242310523986816
# epoch 6 step 1600: save currently the best model to 'model.pt'
# epoch 6 (249/272) | step 1610 | avg_nll=5.37 avg_ppl=2.09 speed=2592.75 words/sec time_elapsed=105.25 sec
# epoch 6 (259/272) | step 1620 | avg_nll=6.40 avg_ppl=2.37 speed=5154.12 words/sec time_elapsed=105.71 sec
# epoch 6 (269/272) | step 1630 | avg_nll=5.32 avg_ppl=2.10 speed=4781.75 words/sec time_elapsed=106.19 sec
# epoch 7 (7/272) | step 1640 | avg_nll=3.39 avg_ppl=1.60 speed=4651.07 words/sec time_elapsed=106.69 sec
# epoch 7 (17/272) | step 1650 | avg_nll=3.28 avg_ppl=1.57 speed=4940.67 words/sec time_elapsed=107.16 sec
# epoch 7 (27/272) | step 1660 | avg_nll=3.42 avg_ppl=1.60 speed=5010.38 words/sec time_elapsed=107.62 sec
# epoch 7 (37/272) | step 1670 | avg_nll=2.88 avg_ppl=1.50 speed=4898.42 words/sec time_elapsed=108.09 sec
# epoch 7 (47/272) | step 1680 | avg_nll=3.31 avg_ppl=1.58 speed=4635.09 words/sec time_elapsed=108.59 sec
# epoch 7 (57/272) | step 1690 | avg_nll=2.91 avg_ppl=1.49 speed=3842.72 words/sec time_elapsed=109.20 sec
# epoch 7 (67/272) | step 1700 | avg_nll=2.85 avg_ppl=1.49 speed=3643.28 words/sec time_elapsed=109.83 sec
# Begin validation ...
# validation: step 1700 | dev_ppl=3.7773702144622803
# epoch 7 step 1700: save currently the best model to 'model.pt'
# epoch 7 (77/272) | step 1710 | avg_nll=3.41 avg_ppl=1.59 speed=1789.73 words/sec time_elapsed=111.15 sec
# epoch 7 (87/272) | step 1720 | avg_nll=3.19 avg_ppl=1.55 speed=3875.88 words/sec time_elapsed=111.75 sec
# epoch 7 (97/272) | step 1730 | avg_nll=3.24 avg_ppl=1.57 speed=5034.25 words/sec time_elapsed=112.21 sec
# epoch 7 (107/272) | step 1740 | avg_nll=3.19 avg_ppl=1.56 speed=4935.51 words/sec time_elapsed=112.67 sec
# epoch 7 (117/272) | step 1750 | avg_nll=3.64 avg_ppl=1.63 speed=5203.09 words/sec time_elapsed=113.13 sec
# epoch 7 (127/272) | step 1760 | avg_nll=3.28 avg_ppl=1.57 speed=4807.59 words/sec time_elapsed=113.61 sec
# epoch 7 (137/272) | step 1770 | avg_nll=3.66 avg_ppl=1.66 speed=4985.28 words/sec time_elapsed=114.07 sec
# epoch 7 (147/272) | step 1780 | avg_nll=3.35 avg_ppl=1.60 speed=4929.93 words/sec time_elapsed=114.54 sec
# epoch 7 (157/272) | step 1790 | avg_nll=3.59 avg_ppl=1.65 speed=4943.95 words/sec time_elapsed=115.00 sec
# epoch 7 (167/272) | step 1800 | avg_nll=3.52 avg_ppl=1.62 speed=5077.87 words/sec time_elapsed=115.46 sec
# Begin validation ...
# validation: step 1800 | dev_ppl=3.712738275527954
# epoch 7 step 1800: save currently the best model to 'model.pt'
# epoch 7 (177/272) | step 1810 | avg_nll=3.21 avg_ppl=1.56 speed=2558.40 words/sec time_elapsed=116.37 sec
# epoch 7 (187/272) | step 1820 | avg_nll=3.70 avg_ppl=1.67 speed=4887.04 words/sec time_elapsed=116.84 sec
# epoch 7 (197/272) | step 1830 | avg_nll=3.53 avg_ppl=1.62 speed=5137.67 words/sec time_elapsed=117.30 sec
# epoch 7 (207/272) | step 1840 | avg_nll=3.29 avg_ppl=1.59 speed=4838.97 words/sec time_elapsed=117.77 sec
# epoch 7 (217/272) | step 1850 | avg_nll=3.54 avg_ppl=1.64 speed=5057.82 words/sec time_elapsed=118.22 sec
# epoch 7 (227/272) | step 1860 | avg_nll=3.74 avg_ppl=1.69 speed=4821.11 words/sec time_elapsed=118.70 sec
# epoch 7 (237/272) | step 1870 | avg_nll=3.57 avg_ppl=1.63 speed=4866.25 words/sec time_elapsed=119.18 sec
# epoch 7 (247/272) | step 1880 | avg_nll=3.66 avg_ppl=1.66 speed=2729.27 words/sec time_elapsed=120.02 sec
# epoch 7 (257/272) | step 1890 | avg_nll=3.35 avg_ppl=1.59 speed=4174.05 words/sec time_elapsed=120.58 sec
# epoch 7 (267/272) | step 1900 | avg_nll=3.78 avg_ppl=1.67 speed=3337.54 words/sec time_elapsed=121.29 sec
# Begin validation ...
# validation: step 1900 | dev_ppl=3.7559030055999756
# epoch 8 (5/272) | step 1910 | avg_nll=2.95 avg_ppl=1.51 speed=1592.36 words/sec time_elapsed=122.73 sec
# epoch 8 (15/272) | step 1920 | avg_nll=1.98 avg_ppl=1.32 speed=3380.95 words/sec time_elapsed=123.41 sec
# epoch 8 (25/272) | step 1930 | avg_nll=1.82 avg_ppl=1.29 speed=3099.55 words/sec time_elapsed=124.14 sec
# epoch 8 (35/272) | step 1940 | avg_nll=2.06 avg_ppl=1.33 speed=3964.90 words/sec time_elapsed=124.73 sec
# epoch 8 (45/272) | step 1950 | avg_nll=2.06 avg_ppl=1.33 speed=4884.50 words/sec time_elapsed=125.20 sec
# epoch 8 (55/272) | step 1960 | avg_nll=1.99 avg_ppl=1.31 speed=5036.59 words/sec time_elapsed=125.66 sec
# epoch 8 (65/272) | step 1970 | avg_nll=1.91 avg_ppl=1.30 speed=4924.54 words/sec time_elapsed=126.13 sec
# epoch 8 (75/272) | step 1980 | avg_nll=2.12 avg_ppl=1.33 speed=5221.47 words/sec time_elapsed=126.59 sec
# epoch 8 (85/272) | step 1990 | avg_nll=2.28 avg_ppl=1.37 speed=4910.03 words/sec time_elapsed=127.06 sec
# epoch 8 (95/272) | step 2000 | avg_nll=2.05 avg_ppl=1.33 speed=5055.19 words/sec time_elapsed=127.51 sec
# Begin validation ...
# validation: step 2000 | dev_ppl=3.7110936641693115
# epoch 8 step 2000: save currently the best model to 'model.pt'
# epoch 8 (105/272) | step 2010 | avg_nll=1.92 avg_ppl=1.30 speed=2572.65 words/sec time_elapsed=128.41 sec
# epoch 8 (115/272) | step 2020 | avg_nll=1.97 avg_ppl=1.31 speed=5115.15 words/sec time_elapsed=128.87 sec
# epoch 8 (125/272) | step 2030 | avg_nll=2.05 avg_ppl=1.33 speed=4940.81 words/sec time_elapsed=129.34 sec
# epoch 8 (135/272) | step 2040 | avg_nll=2.04 avg_ppl=1.32 speed=5194.53 words/sec time_elapsed=129.80 sec
# epoch 8 (145/272) | step 2050 | avg_nll=2.02 avg_ppl=1.33 speed=4806.77 words/sec time_elapsed=130.28 sec
# epoch 8 (155/272) | step 2060 | avg_nll=2.41 avg_ppl=1.40 speed=4921.06 words/sec time_elapsed=130.75 sec
# epoch 8 (165/272) | step 2070 | avg_nll=2.26 avg_ppl=1.36 speed=4829.89 words/sec time_elapsed=131.23 sec
# epoch 8 (175/272) | step 2080 | avg_nll=2.29 avg_ppl=1.38 speed=5089.57 words/sec time_elapsed=131.68 sec
# epoch 8 (185/272) | step 2090 | avg_nll=2.39 avg_ppl=1.39 speed=5001.18 words/sec time_elapsed=132.15 sec
# epoch 8 (195/272) | step 2100 | avg_nll=2.26 avg_ppl=1.37 speed=5006.79 words/sec time_elapsed=132.61 sec
# Begin validation ...
# validation: step 2100 | dev_ppl=3.7789807319641113
# epoch 8 (205/272) | step 2110 | avg_nll=2.28 avg_ppl=1.38 speed=3125.90 words/sec time_elapsed=133.34 sec
# epoch 8 (215/272) | step 2120 | avg_nll=2.46 avg_ppl=1.40 speed=5137.69 words/sec time_elapsed=133.80 sec
# epoch 8 (225/272) | step 2130 | avg_nll=2.39 avg_ppl=1.39 speed=4769.16 words/sec time_elapsed=134.29 sec
# epoch 8 (235/272) | step 2140 | avg_nll=2.48 avg_ppl=1.41 speed=3933.04 words/sec time_elapsed=134.87 sec
# epoch 8 (245/272) | step 2150 | avg_nll=2.26 avg_ppl=1.37 speed=3700.53 words/sec time_elapsed=135.49 sec
# epoch 8 (255/272) | step 2160 | avg_nll=2.53 avg_ppl=1.42 speed=3450.08 words/sec time_elapsed=136.16 sec
# epoch 8 (265/272) | step 2170 | avg_nll=2.65 avg_ppl=1.44 speed=3257.64 words/sec time_elapsed=136.87 sec
# epoch 9 (3/272) | step 2180 | avg_nll=2.24 avg_ppl=1.36 speed=4017.58 words/sec time_elapsed=137.45 sec
# epoch 9 (13/272) | step 2190 | avg_nll=1.42 avg_ppl=1.21 speed=5087.32 words/sec time_elapsed=137.91 sec
# epoch 9 (23/272) | step 2200 | avg_nll=1.47 avg_ppl=1.22 speed=5089.30 words/sec time_elapsed=138.38 sec
# Begin validation ...
# validation: step 2200 | dev_ppl=3.71873140335083
# epoch 9 (33/272) | step 2210 | avg_nll=1.31 avg_ppl=1.20 speed=3140.96 words/sec time_elapsed=139.11 sec
# epoch 9 (43/272) | step 2220 | avg_nll=1.41 avg_ppl=1.22 speed=4847.97 words/sec time_elapsed=139.58 sec
# epoch 9 (53/272) | step 2230 | avg_nll=1.28 avg_ppl=1.20 speed=4822.44 words/sec time_elapsed=140.05 sec
# epoch 9 (63/272) | step 2240 | avg_nll=1.21 avg_ppl=1.19 speed=4601.97 words/sec time_elapsed=140.54 sec
# epoch 9 (73/272) | step 2250 | avg_nll=1.42 avg_ppl=1.22 speed=5028.91 words/sec time_elapsed=141.01 sec
# epoch 9 (83/272) | step 2260 | avg_nll=1.44 avg_ppl=1.22 speed=4821.73 words/sec time_elapsed=141.49 sec
# epoch 9 (93/272) | step 2270 | avg_nll=1.21 avg_ppl=1.18 speed=5033.14 words/sec time_elapsed=141.95 sec
# epoch 9 (103/272) | step 2280 | avg_nll=1.51 avg_ppl=1.23 speed=4930.32 words/sec time_elapsed=142.44 sec
# epoch 9 (113/272) | step 2290 | avg_nll=1.37 avg_ppl=1.21 speed=4864.35 words/sec time_elapsed=142.90 sec
# epoch 9 (123/272) | step 2300 | avg_nll=1.43 avg_ppl=1.22 speed=4980.57 words/sec time_elapsed=143.37 sec
# Begin validation ...
# validation: step 2300 | dev_ppl=3.6590023040771484
# epoch 9 step 2300: save currently the best model to 'model.pt'
# epoch 9 (133/272) | step 2310 | avg_nll=1.31 avg_ppl=1.20 speed=2515.23 words/sec time_elapsed=144.29 sec
# epoch 9 (143/272) | step 2320 | avg_nll=1.42 avg_ppl=1.21 speed=4642.72 words/sec time_elapsed=144.79 sec
# epoch 9 (153/272) | step 2330 | avg_nll=1.51 avg_ppl=1.23 speed=5046.31 words/sec time_elapsed=145.24 sec
# epoch 9 (163/272) | step 2340 | avg_nll=1.61 avg_ppl=1.25 speed=4840.80 words/sec time_elapsed=145.71 sec
# epoch 9 (173/272) | step 2350 | avg_nll=1.58 avg_ppl=1.24 speed=5036.19 words/sec time_elapsed=146.17 sec
# epoch 9 (183/272) | step 2360 | avg_nll=1.48 avg_ppl=1.23 speed=4978.40 words/sec time_elapsed=146.64 sec
# epoch 9 (193/272) | step 2370 | avg_nll=1.63 avg_ppl=1.25 speed=5052.83 words/sec time_elapsed=147.10 sec
# epoch 9 (203/272) | step 2380 | avg_nll=1.55 avg_ppl=1.24 speed=3546.24 words/sec time_elapsed=147.76 sec
# epoch 9 (213/272) | step 2390 | avg_nll=1.56 avg_ppl=1.24 speed=3894.26 words/sec time_elapsed=148.36 sec
# epoch 9 (223/272) | step 2400 | avg_nll=1.63 avg_ppl=1.25 speed=3319.66 words/sec time_elapsed=149.06 sec
# Begin validation ...
# validation: step 2400 | dev_ppl=3.7567532062530518
# epoch 9 (233/272) | step 2410 | avg_nll=1.66 avg_ppl=1.26 speed=2305.63 words/sec time_elapsed=150.06 sec
# epoch 9 (243/272) | step 2420 | avg_nll=1.58 avg_ppl=1.24 speed=5113.40 words/sec time_elapsed=150.51 sec
# epoch 9 (253/272) | step 2430 | avg_nll=1.60 avg_ppl=1.25 speed=4906.45 words/sec time_elapsed=150.98 sec
# epoch 9 (263/272) | step 2440 | avg_nll=1.86 avg_ppl=1.29 speed=5113.00 words/sec time_elapsed=151.44 sec
# epoch 10 (1/272) | step 2450 | avg_nll=1.40 avg_ppl=1.21 speed=4908.75 words/sec time_elapsed=151.91 sec
# epoch 10 (11/272) | step 2460 | avg_nll=1.01 avg_ppl=1.15 speed=5169.17 words/sec time_elapsed=152.37 sec
# epoch 10 (21/272) | step 2470 | avg_nll=0.91 avg_ppl=1.13 speed=4843.74 words/sec time_elapsed=152.84 sec
# epoch 10 (31/272) | step 2480 | avg_nll=0.93 avg_ppl=1.14 speed=5079.23 words/sec time_elapsed=153.30 sec
# epoch 10 (41/272) | step 2490 | avg_nll=1.10 avg_ppl=1.16 speed=4836.86 words/sec time_elapsed=153.78 sec
# epoch 10 (51/272) | step 2500 | avg_nll=1.06 avg_ppl=1.15 speed=5204.65 words/sec time_elapsed=154.24 sec
# Begin validation ...
# validation: step 2500 | dev_ppl=3.9330837726593018
# epoch 10 (61/272) | step 2510 | avg_nll=0.92 avg_ppl=1.14 speed=3098.95 words/sec time_elapsed=154.97 sec
# epoch 10 (71/272) | step 2520 | avg_nll=0.99 avg_ppl=1.15 speed=4989.97 words/sec time_elapsed=155.44 sec
# epoch 10 (81/272) | step 2530 | avg_nll=0.92 avg_ppl=1.13 speed=4797.17 words/sec time_elapsed=155.92 sec
# epoch 10 (91/272) | step 2540 | avg_nll=1.03 avg_ppl=1.16 speed=4906.67 words/sec time_elapsed=156.38 sec
# epoch 10 (101/272) | step 2550 | avg_nll=1.09 avg_ppl=1.16 speed=4919.41 words/sec time_elapsed=156.85 sec
# epoch 10 (111/272) | step 2560 | avg_nll=1.12 avg_ppl=1.17 speed=5076.70 words/sec time_elapsed=157.31 sec
# epoch 10 (121/272) | step 2570 | avg_nll=1.02 avg_ppl=1.15 speed=5028.64 words/sec time_elapsed=157.77 sec
# epoch 10 (131/272) | step 2580 | avg_nll=1.17 avg_ppl=1.18 speed=4891.42 words/sec time_elapsed=158.24 sec
# epoch 10 (141/272) | step 2590 | avg_nll=1.09 avg_ppl=1.17 speed=5008.53 words/sec time_elapsed=158.69 sec
# epoch 10 (151/272) | step 2600 | avg_nll=1.08 avg_ppl=1.16 speed=4827.38 words/sec time_elapsed=159.17 sec
# Begin validation ...
# validation: step 2600 | dev_ppl=3.8459279537200928
# epoch 10 (161/272) | step 2610 | avg_nll=1.12 avg_ppl=1.16 speed=3057.68 words/sec time_elapsed=159.95 sec
# epoch 10 (171/272) | step 2620 | avg_nll=1.23 avg_ppl=1.18 speed=3539.71 words/sec time_elapsed=160.61 sec
# epoch 10 (181/272) | step 2630 | avg_nll=1.21 avg_ppl=1.18 speed=3559.15 words/sec time_elapsed=161.25 sec
# epoch 10 (191/272) | step 2640 | avg_nll=1.12 avg_ppl=1.16 speed=3368.23 words/sec time_elapsed=161.95 sec
# epoch 10 (201/272) | step 2650 | avg_nll=1.35 avg_ppl=1.21 speed=3225.22 words/sec time_elapsed=162.67 sec
# epoch 10 (211/272) | step 2660 | avg_nll=1.34 avg_ppl=1.20 speed=4979.93 words/sec time_elapsed=163.15 sec
# epoch 10 (221/272) | step 2670 | avg_nll=1.33 avg_ppl=1.20 speed=5031.17 words/sec time_elapsed=163.61 sec
# epoch 10 (231/272) | step 2680 | avg_nll=1.18 avg_ppl=1.18 speed=4905.41 words/sec time_elapsed=164.08 sec
# epoch 10 (241/272) | step 2690 | avg_nll=1.38 avg_ppl=1.21 speed=5081.28 words/sec time_elapsed=164.53 sec
# epoch 10 (251/272) | step 2700 | avg_nll=1.42 avg_ppl=1.21 speed=5067.12 words/sec time_elapsed=165.00 sec
# Begin validation ...
# validation: step 2700 | dev_ppl=3.89837908744812
# epoch 10 (261/272) | step 2710 | avg_nll=1.52 avg_ppl=1.23 speed=3168.30 words/sec time_elapsed=165.73 sec
# epoch 10 (271/272) | step 2720 | avg_nll=1.49 avg_ppl=1.24 speed=4540.83 words/sec time_elapsed=166.22 sec
# epoch 11 (9/272) | step 2730 | avg_nll=0.97 avg_ppl=1.14 speed=4891.39 words/sec time_elapsed=166.70 sec
# epoch 11 (19/272) | step 2740 | avg_nll=1.06 avg_ppl=1.15 speed=4952.76 words/sec time_elapsed=167.17 sec
# epoch 11 (29/272) | step 2750 | avg_nll=0.72 avg_ppl=1.11 speed=4957.00 words/sec time_elapsed=167.64 sec
# epoch 11 (39/272) | step 2760 | avg_nll=0.87 avg_ppl=1.12 speed=5173.02 words/sec time_elapsed=168.09 sec
# epoch 11 (49/272) | step 2770 | avg_nll=0.93 avg_ppl=1.14 speed=4996.15 words/sec time_elapsed=168.56 sec
# epoch 11 (59/272) | step 2780 | avg_nll=0.90 avg_ppl=1.13 speed=5063.79 words/sec time_elapsed=169.02 sec
# epoch 11 (69/272) | step 2790 | avg_nll=0.96 avg_ppl=1.14 speed=4907.15 words/sec time_elapsed=169.49 sec
# epoch 11 (79/272) | step 2800 | avg_nll=0.88 avg_ppl=1.13 speed=4922.74 words/sec time_elapsed=169.95 sec
# Begin validation ...
# validation: step 2800 | dev_ppl=4.003547191619873
# epoch 11 (89/272) | step 2810 | avg_nll=0.95 avg_ppl=1.14 speed=2990.35 words/sec time_elapsed=170.72 sec
# epoch 11 (99/272) | step 2820 | avg_nll=0.96 avg_ppl=1.14 speed=4991.01 words/sec time_elapsed=171.18 sec
# epoch 11 (109/272) | step 2830 | avg_nll=1.00 avg_ppl=1.15 speed=4888.13 words/sec time_elapsed=171.65 sec
# epoch 11 (119/272) | step 2840 | avg_nll=1.01 avg_ppl=1.15 speed=5116.35 words/sec time_elapsed=172.11 sec
# epoch 11 (129/272) | step 2850 | avg_nll=0.98 avg_ppl=1.15 speed=4883.70 words/sec time_elapsed=172.57 sec
# epoch 11 (139/272) | step 2860 | avg_nll=1.11 avg_ppl=1.17 speed=3676.09 words/sec time_elapsed=173.20 sec
# epoch 11 (149/272) | step 2870 | avg_nll=1.13 avg_ppl=1.16 speed=3852.87 words/sec time_elapsed=173.82 sec
# epoch 11 (159/272) | step 2880 | avg_nll=1.09 avg_ppl=1.17 speed=3363.93 words/sec time_elapsed=174.50 sec
# epoch 11 (169/272) | step 2890 | avg_nll=1.09 avg_ppl=1.16 speed=3138.03 words/sec time_elapsed=175.23 sec
# epoch 11 (179/272) | step 2900 | avg_nll=1.31 avg_ppl=1.20 speed=4919.13 words/sec time_elapsed=175.71 sec
# Begin validation ...
# validation: step 2900 | dev_ppl=4.149539947509766
# epoch 11 (189/272) | step 2910 | avg_nll=1.29 avg_ppl=1.20 speed=3102.42 words/sec time_elapsed=176.45 sec
# epoch 11 (199/272) | step 2920 | avg_nll=1.31 avg_ppl=1.19 speed=5131.25 words/sec time_elapsed=176.91 sec
# epoch 11 (209/272) | step 2930 | avg_nll=1.23 avg_ppl=1.19 speed=4922.94 words/sec time_elapsed=177.38 sec
# epoch 11 (219/272) | step 2940 | avg_nll=1.08 avg_ppl=1.16 speed=4962.10 words/sec time_elapsed=177.85 sec
# epoch 11 (229/272) | step 2950 | avg_nll=1.11 avg_ppl=1.16 speed=5112.31 words/sec time_elapsed=178.31 sec
# epoch 11 (239/272) | step 2960 | avg_nll=1.32 avg_ppl=1.20 speed=4872.64 words/sec time_elapsed=178.78 sec
# epoch 11 (249/272) | step 2970 | avg_nll=1.35 avg_ppl=1.21 speed=4865.67 words/sec time_elapsed=179.25 sec
# epoch 11 (259/272) | step 2980 | avg_nll=1.29 avg_ppl=1.19 speed=4869.41 words/sec time_elapsed=179.72 sec
# epoch 11 (269/272) | step 2990 | avg_nll=1.34 avg_ppl=1.20 speed=5016.41 words/sec time_elapsed=180.19 sec
# epoch 12 (7/272) | step 3000 | avg_nll=0.91 avg_ppl=1.13 speed=5024.17 words/sec time_elapsed=180.66 sec
# Begin validation ...
# validation: step 3000 | dev_ppl=4.207509994506836
# epoch 12 (17/272) | step 3010 | avg_nll=0.99 avg_ppl=1.15 speed=3185.81 words/sec time_elapsed=181.39 sec
# epoch 12 (27/272) | step 3020 | avg_nll=0.92 avg_ppl=1.14 speed=4891.39 words/sec time_elapsed=181.86 sec
# epoch 12 (37/272) | step 3030 | avg_nll=0.75 avg_ppl=1.11 speed=4905.89 words/sec time_elapsed=182.33 sec
# epoch 12 (47/272) | step 3040 | avg_nll=0.85 avg_ppl=1.13 speed=4758.74 words/sec time_elapsed=182.81 sec
# epoch 12 (57/272) | step 3050 | avg_nll=0.78 avg_ppl=1.11 speed=5052.44 words/sec time_elapsed=183.26 sec
# epoch 12 (67/272) | step 3060 | avg_nll=0.97 avg_ppl=1.14 speed=4987.55 words/sec time_elapsed=183.73 sec
# epoch 12 (77/272) | step 3070 | avg_nll=1.00 avg_ppl=1.15 speed=4916.36 words/sec time_elapsed=184.20 sec
# epoch 12 (87/272) | step 3080 | avg_nll=1.09 avg_ppl=1.16 speed=5018.85 words/sec time_elapsed=184.67 sec
# epoch 12 (97/272) | step 3090 | avg_nll=0.97 avg_ppl=1.14 speed=5043.11 words/sec time_elapsed=185.12 sec
# epoch 12 (107/272) | step 3100 | avg_nll=0.89 avg_ppl=1.13 speed=3656.10 words/sec time_elapsed=185.74 sec
# Begin validation ...
# validation: step 3100 | dev_ppl=4.256143569946289
# epoch 12 (117/272) | step 3110 | avg_nll=1.03 avg_ppl=1.15 speed=2409.61 words/sec time_elapsed=186.73 sec
# epoch 12 (127/272) | step 3120 | avg_nll=0.99 avg_ppl=1.15 speed=3188.57 words/sec time_elapsed=187.47 sec
# epoch 12 (137/272) | step 3130 | avg_nll=1.16 avg_ppl=1.18 speed=3794.59 words/sec time_elapsed=188.08 sec
# epoch 12 (147/272) | step 3140 | avg_nll=0.96 avg_ppl=1.14 speed=5103.20 words/sec time_elapsed=188.53 sec
# epoch 12 (157/272) | step 3150 | avg_nll=1.03 avg_ppl=1.16 speed=4855.72 words/sec time_elapsed=189.00 sec
# epoch 12 (167/272) | step 3160 | avg_nll=1.09 avg_ppl=1.16 speed=5083.72 words/sec time_elapsed=189.45 sec
# epoch 12 (177/272) | step 3170 | avg_nll=0.99 avg_ppl=1.15 speed=4882.41 words/sec time_elapsed=189.93 sec
# epoch 12 (187/272) | step 3180 | avg_nll=1.36 avg_ppl=1.20 speed=5139.63 words/sec time_elapsed=190.39 sec
# epoch 12 (197/272) | step 3190 | avg_nll=1.44 avg_ppl=1.22 speed=4951.77 words/sec time_elapsed=190.86 sec
# epoch 12 (207/272) | step 3200 | avg_nll=1.24 avg_ppl=1.19 speed=4994.77 words/sec time_elapsed=191.32 sec
# Begin validation ...
# validation: step 3200 | dev_ppl=4.35507345199585
# epoch 12 (217/272) | step 3210 | avg_nll=1.23 avg_ppl=1.19 speed=3179.83 words/sec time_elapsed=192.05 sec
# epoch 12 (227/272) | step 3220 | avg_nll=1.47 avg_ppl=1.22 speed=5144.50 words/sec time_elapsed=192.51 sec
# epoch 12 (237/272) | step 3230 | avg_nll=1.30 avg_ppl=1.20 speed=4776.07 words/sec time_elapsed=192.99 sec
# epoch 12 (247/272) | step 3240 | avg_nll=1.36 avg_ppl=1.21 speed=4999.37 words/sec time_elapsed=193.44 sec
# epoch 12 (257/272) | step 3250 | avg_nll=1.12 avg_ppl=1.17 speed=4746.12 words/sec time_elapsed=193.93 sec
# epoch 12 (267/272) | step 3260 | avg_nll=1.58 avg_ppl=1.24 speed=5060.53 words/sec time_elapsed=194.39 sec
# epoch 13 (5/272) | step 3270 | avg_nll=1.15 avg_ppl=1.17 speed=5055.30 words/sec time_elapsed=194.85 sec
# epoch 13 (15/272) | step 3280 | avg_nll=0.93 avg_ppl=1.14 speed=4962.70 words/sec time_elapsed=195.31 sec
# epoch 13 (25/272) | step 3290 | avg_nll=1.00 avg_ppl=1.15 speed=4955.23 words/sec time_elapsed=195.77 sec
# epoch 13 (35/272) | step 3300 | avg_nll=0.81 avg_ppl=1.12 speed=4858.05 words/sec time_elapsed=196.24 sec
# Begin validation ...
# validation: step 3300 | dev_ppl=4.44973087310791
# epoch 13 (45/272) | step 3310 | avg_nll=0.97 avg_ppl=1.14 speed=3232.85 words/sec time_elapsed=196.96 sec
# epoch 13 (55/272) | step 3320 | avg_nll=0.95 avg_ppl=1.14 speed=4723.69 words/sec time_elapsed=197.44 sec
# epoch 13 (65/272) | step 3330 | avg_nll=0.83 avg_ppl=1.12 speed=4572.90 words/sec time_elapsed=197.95 sec
# epoch 13 (75/272) | step 3340 | avg_nll=1.05 avg_ppl=1.16 speed=3453.21 words/sec time_elapsed=198.61 sec
# epoch 13 (85/272) | step 3350 | avg_nll=0.92 avg_ppl=1.13 speed=3713.74 words/sec time_elapsed=199.25 sec
# epoch 13 (95/272) | step 3360 | avg_nll=0.84 avg_ppl=1.12 speed=3224.66 words/sec time_elapsed=199.96 sec
# epoch 13 (105/272) | step 3370 | avg_nll=0.84 avg_ppl=1.12 speed=3301.40 words/sec time_elapsed=200.67 sec
# epoch 13 (115/272) | step 3380 | avg_nll=0.90 avg_ppl=1.13 speed=4801.29 words/sec time_elapsed=201.16 sec
# epoch 13 (125/272) | step 3390 | avg_nll=0.88 avg_ppl=1.13 speed=5050.06 words/sec time_elapsed=201.62 sec
# epoch 13 (135/272) | step 3400 | avg_nll=1.08 avg_ppl=1.16 speed=4971.52 words/sec time_elapsed=202.08 sec
# Begin validation ...
# validation: step 3400 | dev_ppl=4.48840856552124
# epoch 13 (145/272) | step 3410 | avg_nll=1.09 avg_ppl=1.16 speed=3150.88 words/sec time_elapsed=202.82 sec
# epoch 13 (155/272) | step 3420 | avg_nll=0.99 avg_ppl=1.14 speed=4914.68 words/sec time_elapsed=203.30 sec
# epoch 13 (165/272) | step 3430 | avg_nll=0.95 avg_ppl=1.14 speed=5011.72 words/sec time_elapsed=203.76 sec
# epoch 13 (175/272) | step 3440 | avg_nll=1.06 avg_ppl=1.16 speed=5072.91 words/sec time_elapsed=204.22 sec
# epoch 13 (185/272) | step 3450 | avg_nll=1.17 avg_ppl=1.17 speed=5152.71 words/sec time_elapsed=204.68 sec
# epoch 13 (195/272) | step 3460 | avg_nll=1.17 avg_ppl=1.17 speed=5136.10 words/sec time_elapsed=205.13 sec
# epoch 13 (205/272) | step 3470 | avg_nll=1.17 avg_ppl=1.17 speed=5008.39 words/sec time_elapsed=205.61 sec
# epoch 13 (215/272) | step 3480 | avg_nll=1.16 avg_ppl=1.18 speed=5047.62 words/sec time_elapsed=206.06 sec
# epoch 13 (225/272) | step 3490 | avg_nll=1.34 avg_ppl=1.21 speed=4873.89 words/sec time_elapsed=206.53 sec
# epoch 13 (235/272) | step 3500 | avg_nll=1.21 avg_ppl=1.18 speed=5016.24 words/sec time_elapsed=206.99 sec
# Begin validation ...
# validation: step 3500 | dev_ppl=4.582921028137207
# epoch 13 (245/272) | step 3510 | avg_nll=1.52 avg_ppl=1.23 speed=3062.91 words/sec time_elapsed=207.75 sec
# epoch 13 (255/272) | step 3520 | avg_nll=1.41 avg_ppl=1.21 speed=5162.60 words/sec time_elapsed=208.20 sec
# epoch 13 (265/272) | step 3530 | avg_nll=1.23 avg_ppl=1.19 speed=4909.99 words/sec time_elapsed=208.67 sec
# epoch 14 (3/272) | step 3540 | avg_nll=1.02 avg_ppl=1.16 speed=4942.96 words/sec time_elapsed=209.13 sec
# epoch 14 (13/272) | step 3550 | avg_nll=0.99 avg_ppl=1.15 speed=4858.21 words/sec time_elapsed=209.61 sec
# epoch 14 (23/272) | step 3560 | avg_nll=0.74 avg_ppl=1.11 speed=5005.12 words/sec time_elapsed=210.06 sec
# epoch 14 (33/272) | step 3570 | avg_nll=0.81 avg_ppl=1.12 speed=4879.82 words/sec time_elapsed=210.53 sec
# epoch 14 (43/272) | step 3580 | avg_nll=0.82 avg_ppl=1.12 speed=3886.33 words/sec time_elapsed=211.13 sec
# epoch 14 (53/272) | step 3590 | avg_nll=0.85 avg_ppl=1.13 speed=3644.26 words/sec time_elapsed=211.76 sec
# epoch 14 (63/272) | step 3600 | avg_nll=0.84 avg_ppl=1.13 speed=3333.86 words/sec time_elapsed=212.44 sec
# Begin validation ...
# validation: step 3600 | dev_ppl=4.676941394805908
# epoch 14 (73/272) | step 3610 | avg_nll=0.86 avg_ppl=1.13 speed=2323.00 words/sec time_elapsed=213.42 sec
# epoch 14 (83/272) | step 3620 | avg_nll=0.91 avg_ppl=1.14 speed=4783.41 words/sec time_elapsed=213.91 sec
# epoch 14 (93/272) | step 3630 | avg_nll=0.85 avg_ppl=1.12 speed=5086.99 words/sec time_elapsed=214.37 sec
# epoch 14 (103/272) | step 3640 | avg_nll=0.91 avg_ppl=1.14 speed=4678.23 words/sec time_elapsed=214.85 sec
# epoch 14 (113/272) | step 3650 | avg_nll=0.81 avg_ppl=1.12 speed=4964.49 words/sec time_elapsed=215.31 sec
# epoch 14 (123/272) | step 3660 | avg_nll=0.90 avg_ppl=1.13 speed=4933.16 words/sec time_elapsed=215.79 sec
# epoch 14 (133/272) | step 3670 | avg_nll=0.91 avg_ppl=1.13 speed=5097.70 words/sec time_elapsed=216.25 sec
# epoch 14 (143/272) | step 3680 | avg_nll=1.12 avg_ppl=1.16 speed=4887.04 words/sec time_elapsed=216.73 sec
# epoch 14 (153/272) | step 3690 | avg_nll=1.00 avg_ppl=1.15 speed=5040.02 words/sec time_elapsed=217.20 sec
# epoch 14 (163/272) | step 3700 | avg_nll=1.03 avg_ppl=1.15 speed=4833.20 words/sec time_elapsed=217.68 sec
# Begin validation ...
# validation: step 3700 | dev_ppl=4.628471374511719
# epoch 14 (173/272) | step 3710 | avg_nll=1.21 avg_ppl=1.18 speed=3179.92 words/sec time_elapsed=218.42 sec
# epoch 14 (183/272) | step 3720 | avg_nll=1.06 avg_ppl=1.16 speed=4781.55 words/sec time_elapsed=218.91 sec
# epoch 14 (193/272) | step 3730 | avg_nll=1.11 avg_ppl=1.16 speed=5011.10 words/sec time_elapsed=219.38 sec
# epoch 14 (203/272) | step 3740 | avg_nll=1.00 avg_ppl=1.15 speed=4662.25 words/sec time_elapsed=219.88 sec
# epoch 14 (213/272) | step 3750 | avg_nll=1.04 avg_ppl=1.15 speed=4961.05 words/sec time_elapsed=220.35 sec
# epoch 14 (223/272) | step 3760 | avg_nll=1.15 avg_ppl=1.17 speed=4672.18 words/sec time_elapsed=220.85 sec
# epoch 14 (233/272) | step 3770 | avg_nll=1.23 avg_ppl=1.18 speed=5001.42 words/sec time_elapsed=221.31 sec
# epoch 14 (243/272) | step 3780 | avg_nll=1.24 avg_ppl=1.19 speed=4769.68 words/sec time_elapsed=221.79 sec
# epoch 14 (253/272) | step 3790 | avg_nll=1.24 avg_ppl=1.18 speed=5084.78 words/sec time_elapsed=222.25 sec
# epoch 14 (263/272) | step 3800 | avg_nll=1.40 avg_ppl=1.22 speed=4812.34 words/sec time_elapsed=222.73 sec
# Begin validation ...
# validation: step 3800 | dev_ppl=4.626417636871338
# epoch 15 (1/272) | step 3810 | avg_nll=1.12 avg_ppl=1.17 speed=2660.03 words/sec time_elapsed=223.59 sec
# epoch 15 (11/272) | step 3820 | avg_nll=0.88 avg_ppl=1.13 speed=3769.85 words/sec time_elapsed=224.21 sec
# epoch 15 (21/272) | step 3830 | avg_nll=0.93 avg_ppl=1.13 speed=3528.59 words/sec time_elapsed=224.88 sec
# epoch 15 (31/272) | step 3840 | avg_nll=0.86 avg_ppl=1.13 speed=3325.99 words/sec time_elapsed=225.57 sec
# epoch 15 (41/272) | step 3850 | avg_nll=0.83 avg_ppl=1.12 speed=3687.27 words/sec time_elapsed=226.20 sec
# epoch 15 (51/272) | step 3860 | avg_nll=0.83 avg_ppl=1.12 speed=4848.83 words/sec time_elapsed=226.66 sec
# epoch 15 (61/272) | step 3870 | avg_nll=0.90 avg_ppl=1.13 speed=4937.18 words/sec time_elapsed=227.13 sec
# epoch 15 (71/272) | step 3880 | avg_nll=0.92 avg_ppl=1.13 speed=5107.68 words/sec time_elapsed=227.59 sec
# epoch 15 (81/272) | step 3890 | avg_nll=1.02 avg_ppl=1.15 speed=4946.47 words/sec time_elapsed=228.05 sec
# epoch 15 (91/272) | step 3900 | avg_nll=0.90 avg_ppl=1.13 speed=4983.49 words/sec time_elapsed=228.52 sec
# Begin validation ...
# validation: step 3900 | dev_ppl=4.496364116668701
# epoch 15 (101/272) | step 3910 | avg_nll=0.91 avg_ppl=1.13 speed=3150.50 words/sec time_elapsed=229.26 sec
# ...
# epoch 17 (237/272) | step 4590 | avg_nll=0.85 avg_ppl=1.13 speed=4788.66 words/sec time_elapsed=265.13 sec
# epoch 17 (247/272) | step 4600 | avg_nll=0.92 avg_ppl=1.14 speed=5107.62 words/sec time_elapsed=265.58 sec
# Begin validation ...
# validation: step 4600 | dev_ppl=4.999550819396973
# epoch 17 (257/272) | step 4610 | avg_nll=0.81 avg_ppl=1.12 speed=3214.52 words/sec time_elapsed=266.31 sec
# epoch 17 (267/272) | step 4620 | avg_nll=0.88 avg_ppl=1.13 speed=4912.18 words/sec time_elapsed=266.77 sec
# epoch 18 (5/272) | step 4630 | avg_nll=0.75 avg_ppl=1.11 speed=4898.65 words/sec time_elapsed=267.24 sec
# epoch 18 (15/272) | step 4640 | avg_nll=0.55 avg_ppl=1.08 speed=4991.69 words/sec time_elapsed=267.70 sec
# epoch 18 (25/272) | step 4650 | avg_nll=0.70 avg_ppl=1.10 speed=4947.55 words/sec time_elapsed=268.17 sec
# epoch 18 (35/272) | step 4660 | avg_nll=0.66 avg_ppl=1.09 speed=5087.67 words/sec time_elapsed=268.63 sec
# epoch 18 (45/272) | step 4670 | avg_nll=0.70 avg_ppl=1.10 speed=5043.90 words/sec time_elapsed=269.08 sec
# epoch 18 (55/272) | step 4680 | avg_nll=0.60 avg_ppl=1.09 speed=4899.78 words/sec time_elapsed=269.55 sec
# epoch 18 (65/272) | step 4690 | avg_nll=0.65 avg_ppl=1.09 speed=4859.35 words/sec time_elapsed=270.03 sec
# epoch 18 (75/272) | step 4700 | avg_nll=0.58 avg_ppl=1.08 speed=5009.12 words/sec time_elapsed=270.49 sec
# Begin validation ...
# validation: step 4700 | dev_ppl=4.930633544921875
# epoch 18 (85/272) | step 4710 | avg_nll=0.71 avg_ppl=1.10 speed=3093.76 words/sec time_elapsed=271.23 sec
# epoch 18 (95/272) | step 4720 | avg_nll=0.79 avg_ppl=1.11 speed=5126.98 words/sec time_elapsed=271.69 sec
# epoch 18 (105/272) | step 4730 | avg_nll=0.64 avg_ppl=1.09 speed=5098.98 words/sec time_elapsed=272.14 sec
# epoch 18 (115/272) | step 4740 | avg_nll=0.61 avg_ppl=1.09 speed=4995.29 words/sec time_elapsed=272.62 sec
# epoch 18 (125/272) | step 4750 | avg_nll=0.81 avg_ppl=1.12 speed=4955.61 words/sec time_elapsed=273.08 sec
# epoch 18 (135/272) | step 4760 | avg_nll=0.62 avg_ppl=1.09 speed=4884.66 words/sec time_elapsed=273.55 sec
# epoch 18 (145/272) | step 4770 | avg_nll=0.86 avg_ppl=1.13 speed=5065.29 words/sec time_elapsed=274.01 sec
# epoch 18 (155/272) | step 4780 | avg_nll=0.80 avg_ppl=1.12 speed=3925.48 words/sec time_elapsed=274.60 sec
# epoch 18 (165/272) | step 4790 | avg_nll=0.71 avg_ppl=1.10 speed=3683.77 words/sec time_elapsed=275.23 sec
# epoch 18 (175/272) | step 4800 | avg_nll=0.79 avg_ppl=1.11 speed=3470.56 words/sec time_elapsed=275.91 sec
# Begin validation ...
# validation: step 4800 | dev_ppl=5.116262912750244
# epoch 18 (185/272) | step 4810 | avg_nll=0.91 avg_ppl=1.13 speed=2286.40 words/sec time_elapsed=276.93 sec
# epoch 18 (195/272) | step 4820 | avg_nll=0.75 avg_ppl=1.11 speed=5003.78 words/sec time_elapsed=277.39 sec
# epoch 18 (205/272) | step 4830 | avg_nll=0.84 avg_ppl=1.12 speed=4822.89 words/sec time_elapsed=277.87 sec
# epoch 18 (215/272) | step 4840 | avg_nll=0.81 avg_ppl=1.12 speed=5151.28 words/sec time_elapsed=278.32 sec
# epoch 18 (225/272) | step 4850 | avg_nll=0.89 avg_ppl=1.13 speed=4886.78 words/sec time_elapsed=278.80 sec
# epoch 18 (235/272) | step 4860 | avg_nll=0.84 avg_ppl=1.12 speed=5198.14 words/sec time_elapsed=279.25 sec
# epoch 18 (245/272) | step 4870 | avg_nll=0.85 avg_ppl=1.12 speed=5095.51 words/sec time_elapsed=279.71 sec
# epoch 18 (255/272) | step 4880 | avg_nll=0.85 avg_ppl=1.13 speed=4904.71 words/sec time_elapsed=280.18 sec
# epoch 18 (265/272) | step 4890 | avg_nll=0.91 avg_ppl=1.13 speed=4887.75 words/sec time_elapsed=280.65 sec
# epoch 19 (3/272) | step 4900 | avg_nll=0.77 avg_ppl=1.11 speed=4855.83 words/sec time_elapsed=281.12 sec
# Begin validation ...
# validation: step 4900 | dev_ppl=5.169719219207764
# epoch 19 (13/272) | step 4910 | avg_nll=0.60 avg_ppl=1.09 speed=3162.73 words/sec time_elapsed=281.85 sec
# epoch 19 (23/272) | step 4920 | avg_nll=0.62 avg_ppl=1.09 speed=5052.18 words/sec time_elapsed=282.30 sec
# epoch 19 (33/272) | step 4930 | avg_nll=0.74 avg_ppl=1.11 speed=4911.32 words/sec time_elapsed=282.77 sec
# epoch 19 (43/272) | step 4940 | avg_nll=0.55 avg_ppl=1.08 speed=5067.62 words/sec time_elapsed=283.24 sec
# epoch 19 (53/272) | step 4950 | avg_nll=0.55 avg_ppl=1.08 speed=4861.98 words/sec time_elapsed=283.71 sec
# epoch 19 (63/272) | step 4960 | avg_nll=0.64 avg_ppl=1.09 speed=5156.75 words/sec time_elapsed=284.17 sec
# epoch 19 (73/272) | step 4970 | avg_nll=0.62 avg_ppl=1.09 speed=5078.10 words/sec time_elapsed=284.62 sec
# epoch 19 (83/272) | step 4980 | avg_nll=0.60 avg_ppl=1.09 speed=4868.13 words/sec time_elapsed=285.09 sec
# epoch 19 (93/272) | step 4990 | avg_nll=0.75 avg_ppl=1.11 speed=5160.77 words/sec time_elapsed=285.54 sec
# epoch 19 (103/272) | step 5000 | avg_nll=0.68 avg_ppl=1.10 speed=4751.47 words/sec time_elapsed=286.02 sec
# Begin validation ...
# validation: step 5000 | dev_ppl=5.271330833435059
# epoch 19 (113/272) | step 5010 | avg_nll=0.73 avg_ppl=1.11 speed=3039.89 words/sec time_elapsed=286.78 sec
# epoch 19 (123/272) | step 5020 | avg_nll=0.59 avg_ppl=1.09 speed=3501.68 words/sec time_elapsed=287.44 sec
# epoch 19 (133/272) | step 5030 | avg_nll=0.62 avg_ppl=1.09 speed=3604.54 words/sec time_elapsed=288.08 sec
# epoch 19 (143/272) | step 5040 | avg_nll=0.74 avg_ppl=1.11 speed=3325.16 words/sec time_elapsed=288.79 sec
# epoch 19 (153/272) | step 5050 | avg_nll=0.82 avg_ppl=1.12 speed=3355.72 words/sec time_elapsed=289.48 sec
# epoch 19 (163/272) | step 5060 | avg_nll=0.72 avg_ppl=1.10 speed=4818.05 words/sec time_elapsed=289.97 sec
# epoch 19 (173/272) | step 5070 | avg_nll=0.66 avg_ppl=1.10 speed=5044.65 words/sec time_elapsed=290.43 sec
# epoch 19 (183/272) | step 5080 | avg_nll=0.83 avg_ppl=1.12 speed=4898.97 words/sec time_elapsed=290.91 sec
# epoch 19 (193/272) | step 5090 | avg_nll=0.70 avg_ppl=1.10 speed=4675.21 words/sec time_elapsed=291.40 sec
# epoch 19 (203/272) | step 5100 | avg_nll=0.74 avg_ppl=1.11 speed=4927.99 words/sec time_elapsed=291.86 sec
# Begin validation ...
# validation: step 5100 | dev_ppl=5.11797571182251
# epoch 19 (213/272) | step 5110 | avg_nll=0.78 avg_ppl=1.11 speed=3195.53 words/sec time_elapsed=292.59 sec
# epoch 19 (223/272) | step 5120 | avg_nll=0.92 avg_ppl=1.13 speed=4949.96 words/sec time_elapsed=293.06 sec
# epoch 19 (233/272) | step 5130 | avg_nll=0.84 avg_ppl=1.12 speed=5155.94 words/sec time_elapsed=293.51 sec
# epoch 19 (243/272) | step 5140 | avg_nll=0.79 avg_ppl=1.11 speed=5138.96 words/sec time_elapsed=293.96 sec
# epoch 19 (253/272) | step 5150 | avg_nll=0.78 avg_ppl=1.11 speed=5086.89 words/sec time_elapsed=294.43 sec
# epoch 19 (263/272) | step 5160 | avg_nll=0.98 avg_ppl=1.15 speed=4927.38 words/sec time_elapsed=294.89 sec
# epoch 20 (1/272) | step 5170 | avg_nll=0.94 avg_ppl=1.14 speed=4916.97 words/sec time_elapsed=295.37 sec
# epoch 20 (11/272) | step 5180 | avg_nll=0.72 avg_ppl=1.10 speed=5101.47 words/sec time_elapsed=295.83 sec
# epoch 20 (21/272) | step 5190 | avg_nll=0.59 avg_ppl=1.09 speed=4912.13 words/sec time_elapsed=296.29 sec
# epoch 20 (31/272) | step 5200 | avg_nll=0.75 avg_ppl=1.11 speed=5020.36 words/sec time_elapsed=296.75 sec
# Begin validation ...
# validation: step 5200 | dev_ppl=5.258000373840332
# epoch 20 (41/272) | step 5210 | avg_nll=0.64 avg_ppl=1.09 speed=3207.23 words/sec time_elapsed=297.47 sec
# epoch 20 (51/272) | step 5220 | avg_nll=0.66 avg_ppl=1.10 speed=4935.99 words/sec time_elapsed=297.93 sec
# epoch 20 (61/272) | step 5230 | avg_nll=0.92 avg_ppl=1.13 speed=5004.73 words/sec time_elapsed=298.40 sec
# epoch 20 (71/272) | step 5240 | avg_nll=0.79 avg_ppl=1.12 speed=4914.00 words/sec time_elapsed=298.87 sec
# epoch 20 (81/272) | step 5250 | avg_nll=0.79 avg_ppl=1.11 speed=4936.90 words/sec time_elapsed=299.34 sec
# epoch 20 (91/272) | step 5260 | avg_nll=0.63 avg_ppl=1.09 speed=3549.44 words/sec time_elapsed=299.98 sec
# epoch 20 (101/272) | step 5270 | avg_nll=0.78 avg_ppl=1.11 speed=3766.82 words/sec time_elapsed=300.60 sec
# epoch 20 (111/272) | step 5280 | avg_nll=0.70 avg_ppl=1.10 speed=3279.57 words/sec time_elapsed=301.31 sec
# epoch 20 (121/272) | step 5290 | avg_nll=0.72 avg_ppl=1.10 speed=3211.25 words/sec time_elapsed=302.04 sec
# epoch 20 (131/272) | step 5300 | avg_nll=0.84 avg_ppl=1.12 speed=4957.20 words/sec time_elapsed=302.52 sec
# Begin validation ...
# validation: step 5300 | dev_ppl=5.158574104309082
# epoch 20 (141/272) | step 5310 | avg_nll=0.74 avg_ppl=1.11 speed=3102.82 words/sec time_elapsed=303.25 sec
# epoch 20 (151/272) | step 5320 | avg_nll=0.62 avg_ppl=1.09 speed=4715.02 words/sec time_elapsed=303.73 sec
# epoch 20 (161/272) | step 5330 | avg_nll=0.68 avg_ppl=1.10 speed=5267.57 words/sec time_elapsed=304.18 sec
# epoch 20 (171/272) | step 5340 | avg_nll=0.85 avg_ppl=1.12 speed=5117.31 words/sec time_elapsed=304.64 sec
# epoch 20 (181/272) | step 5350 | avg_nll=0.89 avg_ppl=1.13 speed=4973.32 words/sec time_elapsed=305.11 sec
# epoch 20 (191/272) | step 5360 | avg_nll=0.89 avg_ppl=1.13 speed=4964.70 words/sec time_elapsed=305.58 sec
# epoch 20 (201/272) | step 5370 | avg_nll=0.79 avg_ppl=1.12 speed=5090.43 words/sec time_elapsed=306.04 sec
# epoch 20 (211/272) | step 5380 | avg_nll=0.92 avg_ppl=1.14 speed=4650.84 words/sec time_elapsed=306.53 sec
# epoch 20 (221/272) | step 5390 | avg_nll=1.09 avg_ppl=1.16 speed=4813.20 words/sec time_elapsed=307.00 sec
# epoch 20 (231/272) | step 5400 | avg_nll=0.92 avg_ppl=1.14 speed=4982.08 words/sec time_elapsed=307.47 sec
# Begin validation ...
# validation: step 5400 | dev_ppl=5.2578206062316895
# epoch 20 (241/272) | step 5410 | avg_nll=0.93 avg_ppl=1.14 speed=3220.16 words/sec time_elapsed=308.19 sec
# epoch 20 (251/272) | step 5420 | avg_nll=1.01 avg_ppl=1.15 speed=5036.14 words/sec time_elapsed=308.65 sec
# epoch 20 (261/272) | step 5430 | avg_nll=1.21 avg_ppl=1.18 speed=4993.94 words/sec time_elapsed=309.12 sec
# epoch 20 (271/272) | step 5440 | avg_nll=0.79 avg_ppl=1.12 speed=4733.29 words/sec time_elapsed=309.60 sec
# epoch 21 (9/272) | step 5450 | avg_nll=0.70 avg_ppl=1.10 speed=5031.52 words/sec time_elapsed=310.07 sec
# epoch 21 (19/272) | step 5460 | avg_nll=0.67 avg_ppl=1.10 speed=4953.48 words/sec time_elapsed=310.53 sec
# epoch 21 (29/272) | step 5470 | avg_nll=0.69 avg_ppl=1.10 speed=5040.86 words/sec time_elapsed=310.99 sec
# epoch 21 (39/272) | step 5480 | avg_nll=0.64 avg_ppl=1.09 speed=4760.99 words/sec time_elapsed=311.48 sec
# epoch 21 (49/272) | step 5490 | avg_nll=0.77 avg_ppl=1.11 speed=4928.53 words/sec time_elapsed=311.96 sec
# epoch 21 (59/272) | step 5500 | avg_nll=0.74 avg_ppl=1.11 speed=3662.95 words/sec time_elapsed=312.59 sec
# Begin validation ...
# validation: step 5500 | dev_ppl=5.098295211791992
# epoch 21 (69/272) | step 5510 | avg_nll=0.58 avg_ppl=1.08 speed=2327.69 words/sec time_elapsed=313.57 sec
# epoch 21 (79/272) | step 5520 | avg_nll=0.78 avg_ppl=1.11 speed=3154.62 words/sec time_elapsed=314.30 sec
# epoch 21 (89/272) | step 5530 | avg_nll=0.67 avg_ppl=1.10 speed=4017.54 words/sec time_elapsed=314.88 sec
# epoch 21 (99/272) | step 5540 | avg_nll=0.59 avg_ppl=1.09 speed=5016.60 words/sec time_elapsed=315.34 sec
# epoch 21 (109/272) | step 5550 | avg_nll=0.67 avg_ppl=1.09 speed=4974.53 words/sec time_elapsed=315.81 sec
# epoch 21 (119/272) | step 5560 | avg_nll=0.89 avg_ppl=1.13 speed=5132.58 words/sec time_elapsed=316.26 sec
# epoch 21 (129/272) | step 5570 | avg_nll=0.77 avg_ppl=1.11 speed=4978.44 words/sec time_elapsed=316.72 sec
# epoch 21 (139/272) | step 5580 | avg_nll=0.74 avg_ppl=1.11 speed=5098.68 words/sec time_elapsed=317.19 sec
# epoch 21 (149/272) | step 5590 | avg_nll=0.81 avg_ppl=1.12 speed=5186.35 words/sec time_elapsed=317.64 sec
# epoch 21 (159/272) | step 5600 | avg_nll=0.84 avg_ppl=1.12 speed=4947.82 words/sec time_elapsed=318.11 sec
# Begin validation ...
# validation: step 5600 | dev_ppl=5.2834343910217285
# epoch 21 (169/272) | step 5610 | avg_nll=0.88 avg_ppl=1.13 speed=3140.94 words/sec time_elapsed=318.84 sec
# epoch 21 (179/272) | step 5620 | avg_nll=1.05 avg_ppl=1.15 speed=5070.09 words/sec time_elapsed=319.30 sec
# epoch 21 (189/272) | step 5630 | avg_nll=0.94 avg_ppl=1.14 speed=4953.38 words/sec time_elapsed=319.77 sec
# epoch 21 (199/272) | step 5640 | avg_nll=0.83 avg_ppl=1.12 speed=4900.75 words/sec time_elapsed=320.24 sec
# epoch 21 (209/272) | step 5650 | avg_nll=0.88 avg_ppl=1.13 speed=4933.82 words/sec time_elapsed=320.70 sec
# epoch 21 (219/272) | step 5660 | avg_nll=0.88 avg_ppl=1.13 speed=4675.16 words/sec time_elapsed=321.21 sec
# epoch 21 (229/272) | step 5670 | avg_nll=1.00 avg_ppl=1.15 speed=4878.44 words/sec time_elapsed=321.68 sec
# epoch 21 (239/272) | step 5680 | avg_nll=0.98 avg_ppl=1.14 speed=4763.02 words/sec time_elapsed=322.18 sec
# epoch 21 (249/272) | step 5690 | avg_nll=0.79 avg_ppl=1.12 speed=4865.33 words/sec time_elapsed=322.64 sec
# epoch 21 (259/272) | step 5700 | avg_nll=0.84 avg_ppl=1.12 speed=4735.02 words/sec time_elapsed=323.12 sec
# Begin validation ...
# validation: step 5700 | dev_ppl=5.172677516937256
# epoch 21 (269/272) | step 5710 | avg_nll=1.09 avg_ppl=1.16 speed=3125.54 words/sec time_elapsed=323.86 sec
# epoch 22 (7/272) | step 5720 | avg_nll=0.45 avg_ppl=1.06 speed=4994.57 words/sec time_elapsed=324.32 sec
# epoch 22 (17/272) | step 5730 | avg_nll=0.71 avg_ppl=1.10 speed=4111.04 words/sec time_elapsed=324.88 sec
# epoch 22 (27/272) | step 5740 | avg_nll=0.56 avg_ppl=1.08 speed=3564.13 words/sec time_elapsed=325.51 sec
# epoch 22 (37/272) | step 5750 | avg_nll=0.66 avg_ppl=1.10 speed=3535.31 words/sec time_elapsed=326.16 sec
# epoch 22 (47/272) | step 5760 | avg_nll=0.57 avg_ppl=1.08 speed=3241.17 words/sec time_elapsed=326.87 sec
# epoch 22 (57/272) | step 5770 | avg_nll=0.54 avg_ppl=1.08 speed=3891.95 words/sec time_elapsed=327.46 sec
# epoch 22 (67/272) | step 5780 | avg_nll=0.60 avg_ppl=1.09 speed=4998.47 words/sec time_elapsed=327.92 sec
# epoch 22 (77/272) | step 5790 | avg_nll=0.53 avg_ppl=1.08 speed=5040.34 words/sec time_elapsed=328.38 sec
# epoch 22 (87/272) | step 5800 | avg_nll=0.62 avg_ppl=1.09 speed=5111.55 words/sec time_elapsed=328.84 sec
# Begin validation ...
# validation: step 5800 | dev_ppl=5.285937786102295
# epoch 22 (97/272) | step 5810 | avg_nll=0.65 avg_ppl=1.09 speed=3160.25 words/sec time_elapsed=329.57 sec
# epoch 22 (107/272) | step 5820 | avg_nll=0.59 avg_ppl=1.08 speed=4992.22 words/sec time_elapsed=330.03 sec
# epoch 22 (117/272) | step 5830 | avg_nll=0.63 avg_ppl=1.09 speed=5072.32 words/sec time_elapsed=330.49 sec
# epoch 22 (127/272) | step 5840 | avg_nll=0.68 avg_ppl=1.10 speed=5064.84 words/sec time_elapsed=330.95 sec
# epoch 22 (137/272) | step 5850 | avg_nll=0.64 avg_ppl=1.09 speed=5052.97 words/sec time_elapsed=331.42 sec
# epoch 22 (147/272) | step 5860 | avg_nll=0.53 avg_ppl=1.08 speed=4850.36 words/sec time_elapsed=331.90 sec
# epoch 22 (157/272) | step 5870 | avg_nll=0.68 avg_ppl=1.10 speed=4880.49 words/sec time_elapsed=332.37 sec
# epoch 22 (167/272) | step 5880 | avg_nll=0.57 avg_ppl=1.08 speed=5042.02 words/sec time_elapsed=332.83 sec
# epoch 22 (177/272) | step 5890 | avg_nll=0.75 avg_ppl=1.11 speed=5009.89 words/sec time_elapsed=333.29 sec
# epoch 22 (187/272) | step 5900 | avg_nll=0.71 avg_ppl=1.10 speed=5216.03 words/sec time_elapsed=333.74 sec
# Begin validation ...
# validation: step 5900 | dev_ppl=5.199132919311523
# epoch 22 (197/272) | step 5910 | avg_nll=0.88 avg_ppl=1.13 speed=3222.79 words/sec time_elapsed=334.47 sec
# epoch 22 (207/272) | step 5920 | avg_nll=0.81 avg_ppl=1.12 speed=5117.07 words/sec time_elapsed=334.93 sec
# epoch 22 (217/272) | step 5930 | avg_nll=0.85 avg_ppl=1.12 speed=5004.13 words/sec time_elapsed=335.40 sec
# epoch 22 (227/272) | step 5940 | avg_nll=0.65 avg_ppl=1.09 speed=4988.93 words/sec time_elapsed=335.86 sec
# epoch 22 (237/272) | step 5950 | avg_nll=0.96 avg_ppl=1.14 speed=4858.65 words/sec time_elapsed=336.34 sec
# epoch 22 (247/272) | step 5960 | avg_nll=0.85 avg_ppl=1.13 speed=4966.11 words/sec time_elapsed=336.80 sec
# epoch 22 (257/272) | step 5970 | avg_nll=0.85 avg_ppl=1.12 speed=4747.98 words/sec time_elapsed=337.29 sec
# epoch 22 (267/272) | step 5980 | avg_nll=0.81 avg_ppl=1.12 speed=3523.96 words/sec time_elapsed=337.95 sec
# Reached maximum number of epochs

# %% [markdown]
# ## Evaluate the model
#
# We have trained a seq2seq model for the NMT task. Now let's evaluate the model on the test set by generating translations with beam search and comparing them to the gold translations using the BLEU score.

# %%
from tqdm import tqdm
from nltk.translate.bleu_score import corpus_bleu

def beam_search(model: EncoderDecoderModel,
                encoder_input_ids: torch.LongTensor,
                beam_width: int = 5,
                max_len: int = 32) -> Tuple[torch.LongTensor, float]:
    """Run beam search on the encoder-decoder model for a single source sequence.

    Args:
        model: The encoder-decoder model.
        encoder_input_ids: The input sequence. Tensor of shape [encoder_sequence_length].
        beam_width: Number of generations to expand at each time step.
        max_len: Stop generation when reaching this length for the generated sequence.

    Returns:
        A tuple (generation, score) where generation is the generated target sequence and
            a tensor of shape [target_sequence_length] and score is the corresponding
            log-probability of this generation.
    """
    model.eval()

    encoder_input_ids = encoder_input_ids.unsqueeze(0) # Add the batch dimension
    encoder_padding_mask = torch.zeros_like(encoder_input_ids, dtype=torch.bool) # No padding
    encoder_outputs = model.forward_encoder(encoder_input_ids, encoder_padding_mask)

    generations = [torch.tensor([target_tokenizer.bos_token_id], device=encoder_input_ids.device)]
    scores = [0.0]

    best_generation = None
    best_score = float('-inf')

    for _ in range(max_len):
        new_generations = []
        new_scores = []
        for score, generation in zip(scores, generations):
            generation = generation.unsqueeze(0) # Add the batch dimension
            padding_mask = torch.zeros_like(generation, dtype=torch.bool) # No padding
            decoder_output = model.forward_decoder(generation, padding_mask, encoder_outputs, encoder_padding_mask)
            last_log_probs = decoder_output[0, -1, :].log_softmax(dim=-1)
            top_log_probs, top_indices = last_log_probs.topk(beam_width, dim=-1)

            new_generations.append(torch.cat([generation.expand(beam_width, -1), top_indices[:,None]], dim=1))
            new_scores.append(score + top_log_probs)

        new_generations = torch.cat(new_generations, dim=0)
        new_scores = torch.cat(new_scores, dim=0)

        ends_with_eos = target_tokenizer.eos_token_id == new_generations[:,-1]

        if ends_with_eos.any():
            new_completed_generations = new_generations[ends_with_eos]
            new_completed_scores = new_scores[ends_with_eos]

            if new_completed_scores.max() > best_score:
                best_score = new_completed_scores.max()
                best_generation = new_completed_generations[new_completed_scores.argmax()]

        if best_score >= new_scores.max():
            break

        scores, indices = torch.topk(new_scores, beam_width, dim=-1)
        generations = new_generations[indices]

    if best_generation is None:
        best_generation = generations[0]
        best_score = scores[0]

    return best_generation, best_score.cpu().item()


def run_generation(model, test_dataset, beam_size=5, max_decoding_time_step=32):
    """Run beam search decoding on the test set, compute BLEU and return reference and candidate target sentences.
    """

    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    print('Use device: %s' % device)

    input_sentences = []
    reference_sentences = []
    candidate_sentences = []

    with torch.no_grad():
        for example in tqdm(test_dataset):
            encoder_input_ids = torch.tensor(example["encoder_input_ids"], device=device)

            generation, _ = beam_search(model, encoder_input_ids, beam_size, max_decoding_time_step)

            # Decode given source sequence and generated target sequence and avoid special tokens

            input_text = "".join(source_tokenizer.decode(token).replace("▁", " ") for token in example["encoder_input_ids"][1:-1])
            reference_text = "".join(target_tokenizer.decode(token).replace("▁", " ") for token in example["decoder_input_ids"][1:-1])
            candidate_text = "".join(target_tokenizer.decode(token).replace("▁", " ") for token in generation[1:-1].cpu())

            reference_sentences.append(reference_text)
            candidate_sentences.append(candidate_text)
            input_sentences.append(input_text)


    bleu_score = corpus_bleu([[ref] for ref in reference_sentences],
                             [candidate for candidate in candidate_sentences])

    return bleu_score, input_sentences, reference_sentences, candidate_sentences

# %%
# Restore the best validation checkpoint
model.load_state_dict(torch.load("model.pt"))

bleu_score, inputs, references, candidates = run_generation(model, tokenized_datasets["test"])
print('\n\nCorpus BLEU: {}'.format(bleu_score * 100))
# Out:
# <ipython-input-18-85e6e566cf06>:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load("model.pt"))
# Use device: cuda:0
# 100%|██████████| 486/486 [02:10<00:00,  3.72it/s]
# Corpus BLEU: 69.1155574963973

# %% [markdown]
# Let's look at some examples. What do you think of the quality of the translations?

# %%
# Feel free to change the range to look at more samples!
for k in range(10, 20):
  print(f"===== Sample {k} =====")
  print(f"Input: {inputs[k]}")
  print(f"Gold: {references[k]}")
  print(f"Pred: {candidates[k]}")
# Out:
# ===== Sample 10 =====
# Input:  vous me mettez mal a l aise .
# Gold:  you re embarrassing me .
# Pred:  you re amusing .
# ===== Sample 11 =====
# Input:  c est toi le professeur .
# Gold:  you re the teacher .
# Pred:  you re the teacher .
# ===== Sample 12 =====
# Input:  elle sourit avec bonheur .
# Gold:  she smiled happily .
# Pred:  she smiled .
# ===== Sample 13 =====
# Input:  je ne suis pas devin .
# Gold:  i m not a psychic .
# Pred:  i m not discouraged .
# ===== Sample 14 =====
# Input:  vous allez perdre .
# Gold:  you re going to lose .
# Pred:  you re going to lose .
# ===== Sample 15 =====
# Input:  vous me touchez .
# Gold:  you re touching me .
# Pred:  you re tou .
# ===== Sample 16 =====
# Input:  je pars aujourd hui .
# Gold:  i m leaving today .
# Pred:  i am leaving today .
# ===== Sample 17 =====
# Input:  je ne suis pas une sainte .
# Gold:  i m no saint .
# Pred:  i m not a saint .
# ===== Sample 18 =====
# Input:  je suis puissant .
# Gold:  i m powerful .
# Pred:  i m powerful .
# ===== Sample 19 =====
# Input:  vous n etes qu un lache .
# Gold:  you re nothing but a coward .
# Pred:  you re just a coward .

# %% [markdown]
# # Questions
#
# Please answer written questions from the assignment in this section. You can alter the provided code to obtain the answers, but be careful not to break anything!
#
# **(b) (4 points)**
#
# - (i)
#     What vocabulary size are we using for the source and target language?
#
# - (ii)
#     Approximately how many source and target tokens are on average contained in a training batch? What proportion of these tokens are `<pad>` tokens on average?
#
# - (iii)
# What is the specific purpose of saving the model parameters in a file `model.pt` throughout training in the code we provide?
#
# **(c) (2 points)**
# Manually look at some results and compare them with the gold answers. What do you think of the quality of the translations? Are these grammatical English sentences? Can you identify any common mistakes?
#
# **(d) (4 points)**
# Consider the provided beam search method. This implementation is not efficient and performs a lot of repeated computation. Identify the issue and propose how you can fix it.
# In particular, describe how would you have to change the arguments and return values of your EncoderDecoderModel and its sub-modules?
